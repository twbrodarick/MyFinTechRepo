# %% [markdown]
# # Going Live with CCXT

# %% [markdown]
# ### Import Libraries and Dependencies

# %%
# Import libraries and dependencies
import ccxt
import os
import pandas as pd

# %% [markdown]
# ### Import Environment Variables

# %%
# Import environment variables
kraken_public_key = os.getenv('KRAKEN_PUBLIC_KEY')
kraken_secret_key = os.getenv('KRAKEN_SECRET_KEY')
print(kraken_public_key)
# Out:
# CYB8w8pstfgnDMm00YSjxFb3mZ1IgZgbXyBD4nGEHTroHfv0+NBjsaoo

# %% [markdown]
# ### Set Public and Private Keys for Kraken Exchange via the CCXT library

# %%
# Set the public and private keys for the API
exchange = ccxt.kraken({
    'apiKey': kraken_public_key,
    'secret': kraken_secret_key,
    'enableRateLimit': True
})

# %% [markdown]
# ### Connect to Kraken and Load Available Cyptocurrency Data

# %%
# Connect to Kraken and load the available cryptocurrencies
crypto_details = exchange.load_markets()

# Import data as a Pandas DataFrame
crypto_df = pd.DataFrame(crypto_details)
crypto_df
# Out:
#                                                       ADA/ETH  \
# active                                                   True
# altname                                                ADAETH
# base                                                      ADA
# baseId                                                    ADA
# darkpool                                                False
# id                                                     ADAETH
# info        {'altname': 'ADAETH', 'wsname': 'ADA/ETH', 'ac...
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 7}
# quote                                                     ETH
# quoteId                                                  XETH
# symbol                                                ADA/ETH
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       ADA/EUR  \
# active                                                   True
# altname                                                ADAEUR
# base                                                      ADA
# baseId                                                    ADA
# darkpool                                                False
# id                                                     ADAEUR
# info        {'altname': 'ADAEUR', 'wsname': 'ADA/EUR', 'ac...
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 6}
# quote                                                     EUR
# quoteId                                                  ZEUR
# symbol                                                ADA/EUR
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       ADA/USD  \
# active                                                   True
# altname                                                ADAUSD
# base                                                      ADA
# baseId                                                    ADA
# darkpool                                                False
# id                                                     ADAUSD
# info        {'altname': 'ADAUSD', 'wsname': 'ADA/USD', 'ac...
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 6}
# quote                                                     USD
# quoteId                                                  ZUSD
# symbol                                                ADA/USD
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       ADA/BTC  \
# active                                                   True
# altname                                                ADAXBT
# base                                                      ADA
# baseId                                                    ADA
# darkpool                                                False
# id                                                     ADAXBT
# info        {'altname': 'ADAXBT', 'wsname': 'ADA/XBT', 'ac...
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 8}
# quote                                                     BTC
# quoteId                                                  XXBT
# symbol                                                ADA/BTC
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                      ALGO/ETH  \
# active                                                   True
# altname                                               ALGOETH
# base                                                     ALGO
# baseId                                                   ALGO
# darkpool                                                False
# id                                                    ALGOETH
# info        {'altname': 'ALGOETH', 'wsname': 'ALGO/ETH', '...
# limits      {'amount': {'min': 50.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 7}
# quote                                                     ETH
# quoteId                                                  XETH
# symbol                                               ALGO/ETH
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                      ALGO/EUR  \
# active                                                   True
# altname                                               ALGOEUR
# base                                                     ALGO
# baseId                                                   ALGO
# darkpool                                                False
# id                                                    ALGOEUR
# info        {'altname': 'ALGOEUR', 'wsname': 'ALGO/EUR', '...
# limits      {'amount': {'min': 50.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     EUR
# quoteId                                                  ZEUR
# symbol                                               ALGO/EUR
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                      ALGO/USD  \
# active                                                   True
# altname                                               ALGOUSD
# base                                                     ALGO
# baseId                                                   ALGO
# darkpool                                                False
# id                                                    ALGOUSD
# info        {'altname': 'ALGOUSD', 'wsname': 'ALGO/USD', '...
# limits      {'amount': {'min': 50.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     USD
# quoteId                                                  ZUSD
# symbol                                               ALGO/USD
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                      ALGO/BTC  \
# active                                                   True
# altname                                               ALGOXBT
# base                                                     ALGO
# baseId                                                   ALGO
# darkpool                                                False
# id                                                    ALGOXBT
# info        {'altname': 'ALGOXBT', 'wsname': 'ALGO/XBT', '...
# limits      {'amount': {'min': 50.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 8}
# quote                                                     BTC
# quoteId                                                  XXBT
# symbol                                               ALGO/BTC
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                      ATOM/ETH  \
# active                                                   True
# altname                                               ATOMETH
# base                                                     ATOM
# baseId                                                   ATOM
# darkpool                                                False
# id                                                    ATOMETH
# info        {'altname': 'ATOMETH', 'wsname': 'ATOM/ETH', '...
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 6}
# quote                                                     ETH
# quoteId                                                  XETH
# symbol                                               ATOM/ETH
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                      ATOM/EUR  ...  \
# active                                                   True  ...
# altname                                               ATOMEUR  ...
# base                                                     ATOM  ...
# baseId                                                   ATOM  ...
# darkpool                                                False  ...
# id                                                    ATOMEUR  ...
# info        {'altname': 'ATOMEUR', 'wsname': 'ATOM/EUR', '...  ...
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...  ...
# maker                                                  0.0016  ...
# percentage                                               True  ...
# precision                           {'amount': 8, 'price': 4}  ...
# quote                                                     EUR  ...
# quoteId                                                  ZEUR  ...
# symbol                                               ATOM/EUR  ...
# taker                                                  0.0026  ...
# tierBased                                                True  ...
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...  ...
#
#                                                       XRP/EUR  \
# active                                                   True
# altname                                                XRPEUR
# base                                                      XRP
# baseId                                                   XXRP
# darkpool                                                False
# id                                                   XXRPZEUR
# info        {'altname': 'XRPEUR', 'wsname': 'XRP/EUR', 'ac...
# limits      {'amount': {'min': 30.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     EUR
# quoteId                                                  ZEUR
# symbol                                                XRP/EUR
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       XRP/JPY  \
# active                                                   True
# altname                                                XRPJPY
# base                                                      XRP
# baseId                                                   XXRP
# darkpool                                                False
# id                                                   XXRPZJPY
# info        {'altname': 'XRPJPY', 'wsname': 'XRP/JPY', 'ac...
# limits      {'amount': {'min': 30.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 3}
# quote                                                     JPY
# quoteId                                                  ZJPY
# symbol                                                XRP/JPY
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       XRP/USD  \
# active                                                   True
# altname                                                XRPUSD
# base                                                      XRP
# baseId                                                   XXRP
# darkpool                                                False
# id                                                   XXRPZUSD
# info        {'altname': 'XRPUSD', 'wsname': 'XRP/USD', 'ac...
# limits      {'amount': {'min': 30.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     USD
# quoteId                                                  ZUSD
# symbol                                                XRP/USD
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       ZEC/BTC  \
# active                                                   True
# altname                                                ZECXBT
# base                                                      ZEC
# baseId                                                   XZEC
# darkpool                                                False
# id                                                   XZECXXBT
# info        {'altname': 'ZECXBT', 'wsname': 'ZEC/XBT', 'ac...
# limits      {'amount': {'min': 0.03, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     BTC
# quoteId                                                  XXBT
# symbol                                                ZEC/BTC
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       ZEC/EUR  \
# active                                                   True
# altname                                                ZECEUR
# base                                                      ZEC
# baseId                                                   XZEC
# darkpool                                                False
# id                                                   XZECZEUR
# info        {'altname': 'ZECEUR', 'wsname': 'ZEC/EUR', 'ac...
# limits      {'amount': {'min': 0.03, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 3}
# quote                                                     EUR
# quoteId                                                  ZEUR
# symbol                                                ZEC/EUR
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       ZEC/USD  \
# active                                                   True
# altname                                                ZECUSD
# base                                                      ZEC
# baseId                                                   XZEC
# darkpool                                                False
# id                                                   XZECZUSD
# info        {'altname': 'ZECUSD', 'wsname': 'ZEC/USD', 'ac...
# limits      {'amount': {'min': 0.03, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 2}
# quote                                                     USD
# quoteId                                                  ZUSD
# symbol                                                ZEC/USD
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       EUR/USD  \
# active                                                   True
# altname                                                EURUSD
# base                                                      EUR
# baseId                                                   ZEUR
# darkpool                                                False
# id                                                   ZEURZUSD
# info        {'altname': 'EURUSD', 'wsname': 'EUR/USD', 'ac...
# limits      {'amount': {'min': 10.0, 'max': 100000000.0}, ...
# maker                                                   0.002
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     USD
# quoteId                                                  ZUSD
# symbol                                                EUR/USD
# taker                                                   0.002
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       GBP/USD  \
# active                                                   True
# altname                                                GBPUSD
# base                                                      GBP
# baseId                                                   ZGBP
# darkpool                                                False
# id                                                   ZGBPZUSD
# info        {'altname': 'GBPUSD', 'wsname': 'GBP/USD', 'ac...
# limits      {'amount': {'min': 10.0, 'max': 100000000.0}, ...
# maker                                                   0.002
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     USD
# quoteId                                                  ZUSD
# symbol                                                GBP/USD
# taker                                                   0.002
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       USD/CAD  \
# active                                                   True
# altname                                                USDCAD
# base                                                      USD
# baseId                                                   ZUSD
# darkpool                                                False
# id                                                   ZUSDZCAD
# info        {'altname': 'USDCAD', 'wsname': 'USD/CAD', 'ac...
# limits      {'amount': {'min': 10.0, 'max': 100000000.0}, ...
# maker                                                   0.002
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     CAD
# quoteId                                                  ZCAD
# symbol                                                USD/CAD
# taker                                                   0.002
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       USD/JPY
# active                                                   True
# altname                                                USDJPY
# base                                                      USD
# baseId                                                   ZUSD
# darkpool                                                False
# id                                                   ZUSDZJPY
# info        {'altname': 'USDJPY', 'wsname': 'USD/JPY', 'ac...
# limits      {'amount': {'min': 10.0, 'max': 100000000.0}, ...
# maker                                                   0.002
# percentage                                               True
# precision                           {'amount': 8, 'price': 3}
# quote                                                     JPY
# quoteId                                                  ZJPY
# symbol                                                USD/JPY
# taker                                                   0.002
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
# [17 rows x 179 columns]

# %% [markdown]
# ### List Available Cryptocurrencies for Trading

# %%
# Print column values of DataFrame
print(type(crypto_df.columns.values))
print(crypto_df.columns.values)
print(len(crypto_df.columns.values))
# Out:
# <class 'numpy.ndarray'>
# ['ADA/ETH' 'ADA/EUR' 'ADA/USD' 'ADA/BTC' 'ALGO/ETH' 'ALGO/EUR' 'ALGO/USD'
#  'ALGO/BTC' 'ATOM/ETH' 'ATOM/EUR' 'ATOM/USD' 'ATOM/BTC' 'AUD/JPY'
#  'AUD/USD' 'BAT/ETH' 'BAT/EUR' 'BAT/USD' 'BAT/BTC' 'BCH/AUD' 'BCH/ETH'
#  'BCH/EUR' 'BCH/GBP' 'BCH/USD' 'BCH/USDT' 'BCH/BTC' 'DAI/EUR' 'DAI/USD'
#  'DAI/USDT' 'DASH/EUR' 'DASH/USD' 'DASH/BTC' 'EOS/ETH' 'EOS/EUR' 'EOS/USD'
#  'EOS/BTC' 'ETH/AUD' 'ETH/CHF' 'ETH/DAI' 'ETH/USDC' 'ETH/USDT' 'EUR/AUD'
#  'EUR/CAD' 'EUR/CHF' 'EUR/GBP' 'EUR/JPY' 'GNO/ETH' 'GNO/EUR' 'GNO/USD'
#  'GNO/BTC' 'ICX/ETH' 'ICX/EUR' 'ICX/USD' 'ICX/BTC' 'LINK/ETH' 'LINK/EUR'
#  'LINK/USD' 'LINK/BTC' 'LSK/ETH' 'LSK/EUR' 'LSK/USD' 'LSK/BTC' 'LTC/AUD'
#  'LTC/ETH' 'LTC/GBP' 'LTC/USDT' 'NANO/ETH' 'NANO/EUR' 'NANO/USD'
#  'NANO/BTC' 'OMG/ETH' 'OMG/EUR' 'OMG/USD' 'OMG/BTC' 'OXT/ETH' 'OXT/EUR'
#  'OXT/USD' 'OXT/BTC' 'PAXG/ETH' 'PAXG/EUR' 'PAXG/USD' 'PAXG/BTC'
#  'QTUM/ETH' 'QTUM/EUR' 'QTUM/USD' 'QTUM/BTC' 'SC/ETH' 'SC/EUR' 'SC/USD'
#  'SC/BTC' 'TRX/ETH' 'TRX/EUR' 'TRX/USD' 'TRX/BTC' 'USDC/EUR' 'USD/CHF'
#  'USDC/USD' 'USDC/USDT' 'USDT/AUD' 'USDT/CAD' 'USDT/CHF' 'USDT/EUR'
#  'USDT/GBP' 'USDT/JPY' 'USDT/USD' 'WAVES/ETH' 'WAVES/EUR' 'WAVES/USD'
#  'WAVES/BTC' 'BTC/AUD' 'BTC/CHF' 'BTC/DAI' 'BTC/USDC' 'BTC/USDT'
#  'DOGE/EUR' 'DOGE/USD' 'ETC/ETH' 'ETC/BTC' 'ETC/EUR' 'ETC/USD' 'ETH/BTC'
#  'ETHXBT.d' 'ETH/CAD' 'ETHCAD.d' 'ETH/EUR' 'ETHEUR.d' 'ETH/GBP' 'ETHGBP.d'
#  'ETH/JPY' 'ETHJPY.d' 'ETH/USD' 'ETHUSD.d' 'LTC/BTC' 'LTC/EUR' 'LTC/USD'
#  'MLN/ETH' 'MLN/BTC' 'MLN/EUR' 'MLN/USD' 'REP/ETH' 'REP/BTC' 'REP/EUR'
#  'REP/USD' 'XRP/AUD' 'XRP/ETH' 'XRP/GBP' 'XRP/USDT' 'XTZ/ETH' 'XTZ/EUR'
#  'XTZ/USD' 'XTZ/BTC' 'BTC/CAD' 'XBTCAD.d' 'BTC/EUR' 'XBTEUR.d' 'BTC/GBP'
#  'XBTGBP.d' 'BTC/JPY' 'XBTJPY.d' 'BTC/USD' 'XBTUSD.d' 'DOGE/BTC' 'XLM/BTC'
#  'XLM/EUR' 'XLM/USD' 'XMR/BTC' 'XMR/EUR' 'XMR/USD' 'XRP/BTC' 'XRP/CAD'
#  'XRP/EUR' 'XRP/JPY' 'XRP/USD' 'ZEC/BTC' 'ZEC/EUR' 'ZEC/USD' 'EUR/USD'
#  'GBP/USD' 'USD/CAD' 'USD/JPY']
# 179

# %%
# Show list of available functions for the current exchange (in this case Kraken)
exchange.has
# Out:
# {'loadMarkets': True,
#  'cancelAllOrders': False,
#  'cancelOrder': True,
#  'cancelOrders': False,
#  'CORS': False,
#  'createDepositAddress': True,
#  'createLimitOrder': True,
#  'createMarketOrder': True,
#  'createOrder': True,
#  'deposit': False,
#  'editOrder': 'emulated',
#  'fetchBalance': True,
#  'fetchClosedOrders': True,
#  'fetchCurrencies': True,
#  'fetchDepositAddress': True,
#  'fetchDeposits': True,
#  'fetchL2OrderBook': True,
#  'fetchLedger': True,
#  'fetchMarkets': True,
#  'fetchMyTrades': True,
#  'fetchOHLCV': True,
#  'fetchOpenOrders': True,
#  'fetchOrder': True,
#  'fetchOrderBook': True,
#  'fetchOrderBooks': False,
#  'fetchOrders': False,
#  'fetchOrderTrades': 'emulated',
#  'fetchStatus': 'emulated',
#  'fetchTicker': True,
#  'fetchTickers': True,
#  'fetchTime': True,
#  'fetchTrades': True,
#  'fetchTradingFee': True,
#  'fetchTradingFees': True,
#  'fetchFundingFee': False,
#  'fetchFundingFees': False,
#  'fetchTradingLimits': False,
#  'fetchTransactions': False,
#  'fetchWithdrawals': True,
#  'privateAPI': True,
#  'publicAPI': True,
#  'withdraw': True,
#  'fetchLedgerEntry': True}

# %% [markdown]
# ### Fetch Historical Data for BTC/USD

# %%
# Fetch daily candlestick bar data from `BTC/USD`
historical_prices = exchange.fetch_ohlcv("BTC/USD", "1d")

# Import the data as a Pandas DataFrame and set the columns
historical_prices_df = pd.DataFrame(
    historical_prices, columns=["timestamp", "open", "high", "low", "close", "volume"]
)
historical_prices_df
# Out:
#          timestamp     open     high     low    close        volume
# 0    1530403200000   6387.0   6433.3  6254.3   6345.8   1940.389407
# 1    1530489600000   6345.8   6678.7  6275.0   6617.7   3636.666731
# 2    1530576000000   6618.7   6670.0  6467.6   6495.5   2754.871147
# 3    1530662400000   6497.0   6790.0  6399.8   6584.2   3811.898492
# 4    1530748800000   6587.0   6715.2  6450.0   6526.2   3316.814603
# 5    1530835200000   6526.2   6639.2  6450.0   6595.4   2358.116240
# 6    1530921600000   6595.4   6838.5  6503.2   6755.1   2229.000309
# 7    1531008000000   6754.1   6777.1  6680.5   6704.7   1770.803462
# 8    1531094400000   6704.7   6800.0  6610.0   6662.5   2209.582337
# 9    1531180800000   6662.5   6684.2  6276.7   6304.6   4426.636214
# 10   1531267200000   6304.6   6400.6  6279.0   6377.9   2466.364549
# 11   1531353600000   6378.0   6378.0  6073.3   6242.5   4293.131038
# 12   1531440000000   6248.2   6356.0  6126.1   6214.9   2993.395471
# 13   1531526400000   6214.9   6329.5  6187.0   6250.4   1472.074474
# 14   1531612800000   6250.4   6386.9  6234.5   6335.4   2272.526239
# 15   1531699200000   6345.2   6750.0  6328.0   6727.0   5205.539935
# 16   1531785600000   6727.0   7475.0  6667.1   7316.9   7189.735509
# 17   1531872000000   7316.2   7599.0  7234.6   7367.4   6059.980054
# 18   1531958400000   7379.9   7548.8  7280.8   7472.3   4114.208097
# 19   1532044800000   7472.3   7670.5  7238.8   7320.0   5351.308730
# 20   1532131200000   7320.0   7447.9  7200.3   7396.7   2408.682980
# 21   1532217600000   7397.7   7581.9  7320.0   7401.1   2277.873599
# 22   1532304000000   7401.1   7844.9  7375.8   7720.0   5412.458702
# 23   1532390400000   7720.0   8491.1  7695.0   8401.8   8238.356491
# 24   1532476800000   8401.8   8496.6  8062.1   8166.0   5746.808282
# 25   1532563200000   8166.0   8315.0  7840.0   7925.0   5576.328027
# 26   1532649600000   7925.1   8274.8  7800.5   8177.0   5405.058273
# 27   1532736000000   8177.1   8250.0  8072.0   8230.8   1768.087786
# 28   1532822400000   8225.3   8290.2  8125.0   8213.5   1710.789077
# 29   1532908800000   8213.5   8274.9  7850.1   8170.0   4493.617610
# ..             ...      ...      ...     ...      ...           ...
# 690  1590019200000   9510.1   9564.0  8800.0   9057.3  11531.614492
# 691  1590105600000   9057.3   9261.2  8925.0   9169.0   5719.656679
# 692  1590192000000   9169.0   9316.0  9072.5   9178.6   3122.865087
# 693  1590278400000   9178.6   9300.0  8645.0   8716.9   6206.154630
# 694  1590364800000   8712.8   8975.0  8644.0   8898.1   5700.813438
# 695  1590451200000   8898.1   9012.0  8686.6   8841.7   4990.950779
# 696  1590537600000   8841.7   9226.0  8810.6   9213.9   6357.828713
# 697  1590624000000   9213.9   9625.0  9109.4   9578.0   7758.153535
# 698  1590710400000   9578.0   9608.6  9312.0   9425.0   5849.831641
# 699  1590796800000   9425.0   9745.0  9330.0   9698.6   4322.500954
# 700  1590883200000   9699.9   9700.0  9385.0   9447.4   3341.754444
# 701  1590969600000   9447.4  10370.0  9414.6  10206.2   7470.530277
# 702  1591056000000  10206.2  10234.5  9300.0   9525.4  11933.232703
# 703  1591142400000   9525.4   9690.0  9310.9   9664.1   3728.824136
# 704  1591228800000   9664.1   9884.7  9465.0   9791.4   5787.207506
# 705  1591315200000   9792.1   9855.0  9550.0   9617.7   4503.178023
# 706  1591401600000   9617.7   9731.2  9527.4   9672.0   2400.798706
# 707  1591488000000   9672.0   9811.0  9386.6   9757.7   4152.662131
# 708  1591574400000   9755.7   9800.0  9626.8   9780.9   3144.668458
# 709  1591660800000   9780.9   9900.4  9560.3   9778.0   5057.997223
# 710  1591747200000   9778.0  10000.0  9694.6   9892.4   4915.294122
# 711  1591833600000   9892.2   9969.0  9090.5   9265.8   9858.114825
# 712  1591920000000   9265.8   9545.0  9234.0   9455.6   4460.345465
# 713  1592006400000   9455.6   9492.8  9353.8   9471.0   1777.198444
# 714  1592092800000   9471.0   9475.0  9230.6   9330.4   2455.330672
# 715  1592179200000   9330.4   9499.9  8905.0   9425.3   8491.516780
# 716  1592265600000   9425.3   9593.0  9385.0   9528.5   5073.752593
# 717  1592352000000   9527.5   9556.8  9233.4   9453.1   4804.838180
# 718  1592438400000   9453.1   9480.0  9268.2   9381.5   3225.598727
# 719  1592524800000   9381.5   9381.5  9350.0   9354.9     48.496951
#
# [720 rows x 6 columns]

# %% [markdown]
# ### Convert Epoch Timestamp to Readable Date Format

# %%
# Convert epoch timestamp to date using the `to_datetime` function and `unit` parameter
historical_prices_df["date"] = pd.to_datetime(
    historical_prices_df["timestamp"], unit="ms"
)
historical_prices_df.head()
# Out:
#        timestamp    open    high     low   close       volume       date
# 0  1530403200000  6387.0  6433.3  6254.3  6345.8  1940.389407 2018-07-01
# 1  1530489600000  6345.8  6678.7  6275.0  6617.7  3636.666731 2018-07-02
# 2  1530576000000  6618.7  6670.0  6467.6  6495.5  2754.871147 2018-07-03
# 3  1530662400000  6497.0  6790.0  6399.8  6584.2  3811.898492 2018-07-04
# 4  1530748800000  6587.0  6715.2  6450.0  6526.2  3316.814603 2018-07-05

# %% [markdown]
# ### Fetch Latest Data for BTC/USD

# %%
# Fetch current price details for `BTC/USD`
current_price = exchange.fetch_ticker('BTC/USD')

# Delete `info` key-value pair
del current_price['info']

current_price
# Out:
# {'symbol': 'BTC/USD',
#  'timestamp': 1592526861372,
#  'datetime': '2020-06-19T00:34:21.372Z',
#  'high': 9480.0,
#  'low': 9268.2,
#  'bid': 9358.9,
#  'bidVolume': None,
#  'ask': 9359.0,
#  'askVolume': None,
#  'vwap': 9385.08459,
#  'open': 9381.5,
#  'close': 9358.9,
#  'last': 9358.9,
#  'previousClose': None,
#  'change': None,
#  'percentage': None,
#  'average': None,
#  'baseVolume': 3608.16955752,
#  'quoteVolume': 33862976.51238807}

# %%
# Import data as a Pandas DataFrame
current_price_df = pd.DataFrame(current_price, index=[0])
current_price_df
# Out:
#     symbol      timestamp                  datetime    high     low     bid  \
# 0  BTC/USD  1592526861372  2020-06-19T00:34:21.372Z  9480.0  9268.2  9358.9
#
#   bidVolume     ask askVolume        vwap    open   close    last  \
# 0      None  9359.0      None  9385.08459  9381.5  9358.9  9358.9
#
#   previousClose change percentage average   baseVolume   quoteVolume
# 0          None   None       None    None  3608.169558  3.386298e+07

# %%
# Fetch balance
exchange.fetch_balance()
# Out:
# {'info': {'ZUSD': '2.2163',
#   'XXRP': '1253.00000000',
#   'XLTC': '0.0000080000',
#   'XETH': '1.6452376200'},
#  'USD': {'free': None, 'used': None, 'total': 2.2163},
#  'XRP': {'free': None, 'used': None, 'total': 1253.0},
#  'LTC': {'free': None, 'used': None, 'total': 8e-06},
#  'ETH': {'free': None, 'used': None, 'total': 1.64523762},
#  'free': {'USD': None, 'XRP': None, 'LTC': None, 'ETH': None},
#  'used': {'USD': None, 'XRP': None, 'LTC': None, 'ETH': None},
#  'total': {'USD': 2.2163, 'XRP': 1253.0, 'LTC': 8e-06, 'ETH': 1.64523762}}

# %%
# Fetch status
exchange.fetch_status()
# Out:
# {'status': 'ok', 'updated': 1592526865000, 'eta': None, 'url': None}

# %%
# Fetch open orders
# exchange.fetch_open_orders()
