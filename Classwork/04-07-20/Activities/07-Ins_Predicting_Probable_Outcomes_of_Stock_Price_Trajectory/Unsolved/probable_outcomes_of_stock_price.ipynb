# %% [markdown]
# ### Instructor Demo: Probable Outcomes of Stock Price Trajectory
#
# This program executes `1000` simulations of stock price trajectory over the next `252` trading days (or year of trading), based on a normal probability distribution of average daily returns derived from the sample mean and standard deviation.

# %%
# Import libraries and dependencies

# %%
# Load .env enviroment variables

# Set Alpaca API key and secret

# %% [markdown]
# ### Check Available Tickers from Alpaca Markets API

# %%
# Get all Asstes


# Keep only tradeable assets
# Out:
# [Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '02b6820c-e5d5-462f-b3d0-d600919dffd7',
#      'marginable': True,
#      'name': 'Direxion Daily Gold Miners Bull 3X Shares of Direxion Shares ETF '
#              'Trust',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NUGT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'd174dc71-0a75-47a7-a43c-5cf9360111bf',
#      'marginable': True,
#      'name': 'ETF Series Solutions Trust Loncar Cancer Immunotherapy ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CNCR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '07844fc5-d49c-41dd-a543-dccaf6aec65c',
#      'marginable': True,
#      'name': 'Co-Diagnostics, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CODX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'd2eb2ae7-fb5e-47d8-a0bf-ff77f0f47f94',
#      'marginable': True,
#      'name': 'Teladoc Health, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'TDOC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'af703b23-48ff-407a-aab4-d740200b45fe',
#      'marginable': True,
#      'name': '1Life Healthcare, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ONEM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'd414546c-2622-4d1a-bf12-2a68636f5a87',
#      'marginable': True,
#      'name': 'CRA International, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CRAI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '3ec017af-f24f-4460-a224-f14385931a4a',
#      'marginable': True,
#      'name': "Sportsman's Warehouse Holdings, Inc. Common Stock",
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SPWH',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'AMEX',
#      'id': '81d4c0f0-a661-4da4-b379-3de39327e4e5',
#      'marginable': True,
#      'name': 'Superior Drilling Products Inc.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SDPI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'f4863c01-fc07-46f2-973d-3f512e8e802d',
#      'marginable': True,
#      'name': 'KKR Real Estate Finance Trust Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'KREF',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '18d9d76d-f4dd-4d97-9209-c58826d43f7d',
#      'marginable': True,
#      'name': 'Northfield Bancorp, Inc. Common Stock (Delaware)',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'NFBK',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': '273b92cc-8a5d-459a-81bd-981d8ed5f89a',
#      'marginable': True,
#      'name': 'iPath Series B S&P 500 VIX Short-Term Futures ETN',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'VXX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'b28f4066-5c6d-479b-a2af-85dc1a8f16fb',
#      'marginable': True,
#      'name': 'SPDR S&P 500 ETF Trust',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SPY',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '9fb8aeae-3c99-49b2-8ba9-cbbfbba188fd',
#      'marginable': True,
#      'name': 'Direxion Daily FTSE  China Bull 3X Shares',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'YINN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '66c2dc19-a4a9-460d-9a4f-f9ba05873ca0',
#      'marginable': True,
#      'name': 'Aptiv PLC',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'APTV',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '719ab4de-ac40-4103-8766-2602fa7f82ad',
#      'marginable': True,
#      'name': 'Genocea Biosciences, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'GNCA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'ab538748-a391-4503-a30c-6f4f7ef7cfef',
#      'marginable': True,
#      'name': 'Gevo, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'GEVO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '00d38a92-789f-4b07-a38f-67cbf923c1d6',
#      'marginable': True,
#      'name': 'JMU Limited ADS',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MFH',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '0d7b78ef-b2dc-428f-b869-f8dab348cd5f',
#      'marginable': True,
#      'name': 'Commercial Metals Company',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CMC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '6a6ad0d7-4f96-48ff-bda1-60f5b423d704',
#      'marginable': True,
#      'name': 'Mudrick Capital Acquisition Corporation Class A Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MUDS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': '20f6cb24-e28d-47a5-baa3-93aa2fbe276a',
#      'marginable': True,
#      'name': 'iShares US & Intl High Yield Corp Bond ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'GHYG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'd41b0607-044c-481c-814e-5b841d0f5304',
#      'marginable': True,
#      'name': 'General American Investors Company, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'GAM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'd59870fe-9add-43f2-960c-b2ec4f29d8d3',
#      'marginable': True,
#      'name': 'Dow Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'DOW',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '3d305736-a5c2-4d6a-8c1c-a5ee3dc7cca5',
#      'marginable': True,
#      'name': 'Carnival Corporation',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CCL',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '7595a8d2-68a6-46d7-910c-6b1958491f5c',
#      'marginable': True,
#      'name': 'Agilent Technologies Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'A',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '5344140c-ca01-4435-8a4a-217d4496bd35',
#      'marginable': True,
#      'name': 'ZOETIS INC.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ZTS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'ad22d1ca-8bfc-45cc-ae7f-5f091bbc8c7c',
#      'marginable': True,
#      'name': 'Bristol-Myers Squibb Co.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BMY',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '9fa47189-3158-444f-8e3f-82cdac2c177c',
#      'marginable': True,
#      'name': 'Direxion Daily Gold Miners Bear 3X Shares of Direxion Shares ETF '
#              'Trust',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'DUST',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '05a360ff-d443-48c2-9eee-361f9e663732',
#      'marginable': True,
#      'name': 'Invesco Exchange-Traded Fund Trust Invesco Water Resources ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'PHO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '8027dfb7-d8e5-4d84-8105-447b8c7ceb73',
#      'marginable': True,
#      'name': 'Insurance Acquisition Corp. Unit',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'INSUU',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '639d865b-fd4c-49b1-9a67-58421d6a01f4',
#      'marginable': True,
#      'name': 'John Hancock Multifactor Developed International ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'JHMD',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'dffad494-70d3-4ed6-ae81-566c3d7d6ffd',
#      'marginable': True,
#      'name': 'Tottenham Acquisition I Limited Ordinary Shares',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'TOTA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '34eabc03-1a25-4d40-a084-ebfd3e340fa8',
#      'marginable': True,
#      'name': 'South Mountain Merger Corp. Unit',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SMMCU',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': '8ac4111d-5cec-4eb5-9779-b9ede683cc1e',
#      'marginable': True,
#      'name': 'Innovator Nasdaq-100 Power Buffer ETF - January',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NJAN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'c26784e2-5b2d-4af2-ac73-d8837a58f1b6',
#      'marginable': True,
#      'name': 'First Trust Exchange-Traded Fund VI First Trust Dorsey Wright '
#              'Momentum & Value ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'DVLU',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'a21032a8-b9f8-424e-8597-b40faec7d22e',
#      'marginable': True,
#      'name': 'MicroSectorsTM U.S. Big Banks Index Inverse ETNs',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'KNAB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '5cb8bef8-004e-4c1a-87cb-e62228fbb266',
#      'marginable': True,
#      'name': 'IQ MacKay Municipal Intermediate ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MMIT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'afd87b2d-4f7c-433c-a31f-83581b007de2',
#      'marginable': True,
#      'name': 'FinServ Acquisition Corp. Unit',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'FSRVU',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '8f5a8aa8-b443-4719-b95e-f9d86a91a969',
#      'marginable': True,
#      'name': 'Silver Spike Acquisition Corp. Class A Ordinary Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SSPK',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'da753873-6ba8-4026-ba6b-9ed78f659a37',
#      'marginable': True,
#      'name': 'iPath Series B Bloomberg Platinum Subindex Total ReturnSM ETN',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'PGM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'd51ac4fb-35bc-443e-9cba-30440bc647df',
#      'marginable': True,
#      'name': 'Tuscan Holdings Corp. II Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'THCA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'AMEX',
#      'id': 'e64da5ec-d517-456d-867f-c3c31ea7637a',
#      'marginable': True,
#      'name': 'Adams Resources & Energy Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': 'b7784ac3-9a1f-49d5-a131-aaf9968e58a5',
#      'marginable': True,
#      'name': 'SPDR S&P Oil & Gas Exploration & Production ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'XOP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '6ae1929e-adcd-4de1-9647-25763c8a4548',
#      'marginable': True,
#      'name': 'Lockheed Martin Corp.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'LMT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '924f54d4-9db2-4fb4-a63a-a00fbc0f22b3',
#      'marginable': True,
#      'name': 'Direxion Daily Brazil Bull 3X Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BRZU',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '3bed4fb2-4093-4433-b887-770ae3defd3a',
#      'marginable': True,
#      'name': 'Boeing Company',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '2f858362-4547-4f20-b19b-14628cb2a073',
#      'marginable': True,
#      'name': 'Ekso Bionics Holdings, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'EKSO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '2963234b-6741-47b4-ab67-a91c88392c62',
#      'marginable': True,
#      'name': 'Itau Unibanco Holding S.A. American Depositary Shares',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ITUB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'a90c2d9c-6774-40c0-9721-ca66e1bfdd2a',
#      'marginable': True,
#      'name': 'AdvisorShares Pure Cannabis ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'YOLO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '4a6d9ae0-938b-4eac-b30f-d497c4362a7c',
#      'marginable': True,
#      'name': 'VanEck Vectors Junior Gold Miners ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'GDXJ',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '5829f367-3ef8-4f08-991f-95e69ac8611a',
#      'marginable': True,
#      'name': 'Consumer Discretionary Select Sector SPDR Fund',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'XLY',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'd2c53484-bd7e-4502-9e66-a0829c413b15',
#      'marginable': True,
#      'name': 'First Trust Exchange-Traded Fund III First Trust RiverFront '
#              'Dynamic Emerging Markets ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'RFEM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'f3668eac-5d4c-48a9-b83e-78ad34237e70',
#      'marginable': True,
#      'name': 'FVCBankcorp, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'FVCB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'cc3b9c70-915c-47ac-8b66-8ae9c17c0ab1',
#      'marginable': True,
#      'name': 'G. Willi-Food International,  Ltd. Ordinary Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'WILC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '78a3c481-0fc8-4b23-871b-b5ce2cc0246a',
#      'marginable': True,
#      'name': 'Arrow Investments Trust Arrow DWA Country Rotation ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'DWCR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '63ab07b9-b1d5-4a3a-95e1-73b60444bcae',
#      'marginable': True,
#      'name': 'Vanguard Scottsdale Funds Vanguard Russell 1000 Value ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'VONV',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '87d97bdf-5628-4ad0-9035-d89b453eb1ee',
#      'marginable': True,
#      'name': 'IBERIABANK Corporation Depositary Shares 6.10% Fixed-to-Floating '
#              'Non-Cumulative Perpetual Preferred Stock, Series D',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'IBKCN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '30441889-b775-46d3-a879-cef3c1bcc92c',
#      'marginable': True,
#      'name': 'Research Solutions, Inc Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'RSSS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'c91f4df3-b255-4eba-b325-edea53331898',
#      'marginable': True,
#      'name': 'Globe Life Inc.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'GL-C',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '0cf42aa3-9816-4f1f-aa84-6482ac9303e9',
#      'marginable': True,
#      'name': 'Intel Corporation Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'INTC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '546c6409-4536-41b0-a427-c6a313838d28',
#      'marginable': True,
#      'name': 'SVB Financial Group Depositary Shs each representing a 1/40th '
#              'interest in a share of 5.25% Fixed-Rate Non-Cumulative Perpetual '
#              'Preferred Stock, Series A',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SIVBP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'cfab11b5-fcaf-48bb-a6c6-4ccf2fe2fc38',
#      'marginable': True,
#      'name': 'First Trust Merger Arbitrage ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MARB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '7429fbcd-d5cc-4089-b7a1-f7cb1a785556',
#      'marginable': True,
#      'name': 'Pope Resources Depositary Receipts of Limited Partnership Units',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'POPE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'ead735e2-b4ab-46ce-bcba-7cb41e40c747',
#      'marginable': True,
#      'name': 'GLOBAL SHIP LEASE, INC. 8.75%  SER B',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'GSL-B',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '63d19f94-1da7-46ee-a9ae-8b1a527e3ce1',
#      'marginable': True,
#      'name': 'BRIGHT HORIZONS FAMILY SOLUTIONS INC.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BFAM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '425fc0f5-b4ef-4958-b3c0-0a8c97cd85b3',
#      'marginable': True,
#      'name': 'ProShares RAFI Long/Short',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'RALS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '74869daf-b68e-4f17-8198-4c1dfe667425',
#      'marginable': True,
#      'name': 'Farmland Partners Inc. Series B Participating Preferred Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'FPI-B',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'ae895f0c-6f40-40a5-8dc5-a97240d3ab61',
#      'marginable': True,
#      'name': 'Bank of America Corporation Depositary Shares, each representing '
#              'a 1/1,000 th interest in a share of',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BAC-A',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'e537fc6f-fe8b-4003-927c-872f6749a7ea',
#      'marginable': True,
#      'name': 'Medalist Diversified REIT, Inc. Series A Cumulative Redeemable '
#              'Preferred Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MDRRP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '45075c39-d626-4789-a8b0-03bc9f13fb4a',
#      'marginable': True,
#      'name': 'Janus Henderson Short Duration Income ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'VNLA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '5704cfd2-fe51-44c3-9d8c-8be4fecdd032',
#      'marginable': True,
#      'name': 'Rocky Brands, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'RCKY',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '664c71d6-c62a-4618-9831-756a3ef74ae8',
#      'marginable': True,
#      'name': 'Brown-Forman Corporation Class A',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BF.A',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'f70d234e-e15e-4100-8434-bce148c7dffe',
#      'marginable': True,
#      'name': 'iShares Short-Term Corporate Bond ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'IGSB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '4eca36dd-edaf-4d57-a0cd-5ddce8c27679',
#      'marginable': True,
#      'name': 'MGM RESORTS INTERNATIONAL',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MGM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '5e52d815-9a62-45ee-83a9-fdbf7cb2d33c',
#      'marginable': True,
#      'name': 'Zions Bancorporation 6.95% Fixed-to-Floating Rate Subordinated '
#              'Notes',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ZIONL',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '1381baa9-6a3f-4e5b-a7a6-7f54727273e6',
#      'marginable': True,
#      'name': 'Molecular Templates, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MTEM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'b2015fd4-d4d1-4c80-8e20-394862c1b63d',
#      'marginable': True,
#      'name': 'Sanmina Corporation Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SANM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '22f1489d-0770-4096-9458-4a490d8f09a8',
#      'marginable': True,
#      'name': 'CBIZ, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CBZ',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '2699cd5c-0240-4712-8bee-6e7cf51cfe13',
#      'marginable': True,
#      'name': 'Summit Materials, Inc. Class A Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SUM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '4df570de-5f7d-4645-b098-a0148d7ae677',
#      'marginable': True,
#      'name': 'Invesco MSCI Global Timber ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CUT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '98ce4784-3b9a-4a4f-88ec-f2db2f1e8961',
#      'marginable': True,
#      'name': 'Ameren Corporation',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AEE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'b342d8dd-3483-43f3-9f9b-2591a14ef2aa',
#      'marginable': True,
#      'name': 'Lattice Semiconductor Corporation Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'LSCC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': 'bd26d6a5-adb0-47dd-9fd2-788713c22f2a',
#      'marginable': True,
#      'name': 'Innovator S&P 500 Ultra Buffer ETF - March',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'UMAR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '047860b6-7eba-45fb-88da-17c71251f9c7',
#      'marginable': True,
#      'name': 'Vanguard Communication Services ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'VOX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '814b3adc-bb77-49eb-bb6f-6450e0cebe90',
#      'marginable': True,
#      'name': 'CVR PARTNERS LP',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'UAN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '96d2c7d6-0be2-49f6-ac62-c0d31e2b741b',
#      'marginable': True,
#      'name': 'WisdomTree Europe Hedged SmallCap Equity Fund',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'EUSC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'bded72f6-1fa7-4dac-a55f-80b47504992d',
#      'marginable': True,
#      'name': 'Vanguard S&P Mid-Cap 400 ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IVOO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'BATS',
#      'id': '438db753-89e4-40da-be10-a3ee5f6d5ebb',
#      'marginable': True,
#      'name': 'VanEck Vectors AMT-Free Intermediate Municipal Index ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ITM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '034e2e67-e61e-480b-a7f6-82a7b9ac6363',
#      'marginable': True,
#      'name': 'Independent Bank Corp. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'INDB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '1b10616e-7e2b-42e8-9141-350e97fb5615',
#      'marginable': True,
#      'name': 'ProShares Ulta SmallCap600',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SAA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'bcd778fc-d401-4912-879d-770f8fdf1588',
#      'marginable': True,
#      'name': 'WELLS FARGO & COMPANY Depositary Shares, each representing a '
#              '1/1,000th interest in a share of Non-Cu',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'WFC-O',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'ff56e4d7-509d-4fe2-b854-b5c043770fd2',
#      'marginable': True,
#      'name': 'Tennessee Valley Authority Power Bonds 1998 Series D due June 1, '
#              '2028',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'TVC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'AMEX',
#      'id': 'f2b66692-cc73-4c56-8f6d-572b7058a593',
#      'marginable': True,
#      'name': 'BLUEROCK RESIDENTIAL GROWTH REIT INC 8.250% SR A CUMULATIVE '
#              'REDEEMABLE PFD STK',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BRG-A',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '65efb8e6-1c06-4e90-a9ce-44940d7039c3',
#      'marginable': True,
#      'name': 'STONE HARBOR EMERGING MARKETS INCOME FUND',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'EDF',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'AMEX',
#      'id': 'b9e17620-4841-4574-a755-9ab82c6ec0b2',
#      'marginable': True,
#      'name': 'Flexible Solutions International, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'FSI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'e21e0230-cb7f-4270-bb97-e64104eff51e',
#      'marginable': True,
#      'name': 'J. W. Mays, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MAYS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '904257f8-e025-4236-b239-c306c53ce41c',
#      'marginable': True,
#      'name': 'Athene Holding Ltd. Depositary Shares, Each Representing a '
#              '1/1,000th Interest in a 5.625% Fixed Rate',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ATH-B',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '30b073de-2047-4da8-a80e-a8ebfc09c1f6',
#      'marginable': True,
#      'name': 'Global X Funds Global X Thematic Growth ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'GXTG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'b712acfe-2481-47ae-8151-c3e1b71c7c0d',
#      'marginable': True,
#      'name': 'Materion Corporation',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MTRN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'a3dc580e-26d3-4521-bcc6-7ab64b55ad0e',
#      'marginable': True,
#      'name': 'Insight Select Income Fund',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'INSI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '798dd235-fcab-45b6-8f13-16967a69b0e9',
#      'marginable': True,
#      'name': 'ISTAR INC. 7.50% Series I Cumulative Redeemable Preferred Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'STAR-I',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'c8382768-7d97-42d7-a4a3-f045b9551b7c',
#      'marginable': True,
#      'name': 'Alpha Architect ETF Trust Merlyn.AI Tactical Growth & Income ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SNUG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'ea5bf24b-14ef-4fe0-9d92-5fe7c1ba2769',
#      'marginable': True,
#      'name': 'Fortive Corporation 5.00% Mandatory Convertible Preferred Stock, '
#              'Series A',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'FTV-A',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '619a1269-58b9-4979-ac8b-8797950cdd1d',
#      'marginable': True,
#      'name': 'Hartford Multifactor Developed Markets (ex-US) ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'RODM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '89dd47f1-3e5d-4c31-8fbf-62c6f1649a5f',
#      'marginable': True,
#      'name': 'CorEnergy Infrastructure Trust, Inc Depositary Shares '
#              'representing a 1/100th fractional interest of',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CORR-A',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '18714578-8927-453e-8cad-9541e779b97c',
#      'marginable': True,
#      'name': 'Sensient Technology Corporation',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SXT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '05a42648-475f-48af-be56-b2ddcba80329',
#      'marginable': True,
#      'name': 'Schwab U.S. REIT ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SCHH',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '14acfa60-c0e1-47fb-8f80-ca0831bf3b52',
#      'marginable': True,
#      'name': 'ProShares Ultra VIX Short-Term Futures ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'UVXY',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '35b45787-733f-4ea7-bf0b-ceec0edb0feb',
#      'marginable': True,
#      'name': 'Customers Bancorp, Inc. Fixed-to-Floating Rate Non-Cumulative '
#              'Perpetual Preferred Stock, Series E',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CUBI-E',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '2da35038-7511-48aa-81cf-3f6c377f7c09',
#      'marginable': True,
#      'name': 'Iron Mountain Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'IRM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '02dec2ca-7db0-4ddb-879d-fc93bbb68c2a',
#      'marginable': True,
#      'name': 'Invesco High Income 2024 Target Term Fund',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IHTA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'd42d8369-1aae-444e-ba10-3bf971255cfa',
#      'marginable': True,
#      'name': 'VictoryShares International High Div Volatility Wtd ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CID',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '055439d4-6575-4098-adf2-c8e8223e9ae5',
#      'marginable': True,
#      'name': 'Industrial Logistics Properties Trust Common Shares of Beneficial '
#              'Interest',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ILPT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '506a42f0-933d-44c7-bd1e-5449065b5ce4',
#      'marginable': True,
#      'name': 'Fidelity High Yield Factor ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'FDHY',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '7de48af2-2648-42c6-8319-2719b702617f',
#      'marginable': True,
#      'name': 'Synchronoss Technologies, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SNCR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'b39cefd4-2e14-4bb2-9174-65ebe17f185e',
#      'marginable': True,
#      'name': 'Xtrackers MSCI Emerging Markets ESG Leaders Equity ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'EMSG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'AMEX',
#      'id': 'b1ca5402-cbc2-4558-a8b5-9acd43e9cdfd',
#      'marginable': True,
#      'name': 'Oragenics Inc.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'OGEN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '840ed458-2e1b-4311-abb6-b684392763b1',
#      'marginable': True,
#      'name': 'Megalith Financial Acquisition Corp. Class A Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MFAC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'a7dd2d26-59d5-4c85-8449-cd0cb975fd98',
#      'marginable': True,
#      'name': 'Colgate-Palmolive Company',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CL',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '1472b08f-9e63-4178-b3e1-29b2da918952',
#      'marginable': True,
#      'name': 'Cherry Hill Mortgage Investment Corporation 8.250% Series B '
#              'Fixed-to-Floating Rate Cumulative Redeem',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CHMI-B',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'e20b1f39-89c2-4e58-a7c2-7553af7f8966',
#      'marginable': True,
#      'name': 'MetLife, Inc. Depositary Shares, each representing a 1/1,000th '
#              'interest in a share of 4.75% Non-Cumu',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MET-F',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'c7673e99-f4ed-4f64-bb65-bef2e70fb2bd',
#      'marginable': True,
#      'name': 'Vishay Precision Group, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'VPG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'e72b81c4-464e-4e99-a39d-7a038348e008',
#      'marginable': True,
#      'name': 'Reebonz Holding Limited Ordinary Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'RBZ',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '45e147f3-df80-4c29-a303-8173500038dd',
#      'marginable': True,
#      'name': 'TAUBMAN CENTERS, INC. 6.25%  SER K',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'TCO-K',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '4198a18a-e8d4-4aca-98ad-6408c49dc7a5',
#      'marginable': True,
#      'name': 'Kaman Corp',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'KAMN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'df87a180-ac65-425c-945b-06383a5b0e78',
#      'marginable': True,
#      'name': 'UMH Properties, Inc. 8.0% Series B Cumulative Redeemable '
#              'Preferred Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'UMH-B',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'd982edff-69e4-4261-b596-2b317a4d89f8',
#      'marginable': True,
#      'name': 'NEW SENIOR INVESTMENT GROUP INC.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SNR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '1b98d78e-fda5-47f5-ad2f-4557a3963fe1',
#      'marginable': True,
#      'name': 'Petroleo Brasileiro S.A.-Petrobras',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'PBR.A',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '7521d918-0559-475e-8f6e-a79bf36108f4',
#      'marginable': True,
#      'name': 'Republic First Bancorp, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'FRBK',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'bf2c1697-c582-4148-a45d-72088021a742',
#      'marginable': True,
#      'name': 'Covenant Transportation Group, Inc. Class A Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CVTI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'f751f7d1-2360-402d-a139-48e9d9396994',
#      'marginable': True,
#      'name': 'The Gabelli Global Small and Mid Cap Value Trust 5.450% Series A '
#              'Cumulative Preferred Shares (Liquid',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'GGZ-A',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '91d0b7b9-570f-4af0-a7d7-40239ab6afe6',
#      'marginable': True,
#      'name': 'PGIM QMA Strategic Alpha Large-Cap Core ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'PQLC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'b769adcd-7514-4e56-85ee-dabc29e801e4',
#      'marginable': True,
#      'name': 'Arbor Realty Trust, Inc. 7.75% Series B Preferred',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ABR-B',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'AMEX',
#      'id': '239ae66a-906a-4835-81b5-657b922f3f89',
#      'marginable': True,
#      'name': 'Bluerock Residential Growth REIT Inc. 7.125% Series D, Cumulative '
#              'Preferred Stock ($0.01 par value p',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BRG-D',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'c1bedf3e-51de-4bd0-89d2-2627354bc374',
#      'marginable': True,
#      'name': 'First Trust Active Factor Small Cap ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AFSM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'd53f3196-5c0d-4861-ba15-362b025cc53c',
#      'marginable': True,
#      'name': 'Hoegh LNG Partners LP 8.75 Percent Series A Cumulative Redeemable '
#              'Preferred Units, , representing li',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HMLP-A',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'ba86ee59-1308-4a7e-a10b-f727720f89cc',
#      'marginable': True,
#      'name': 'Citigroup Capital XIII 7.875% Fixed Rate/Floating Rate Trust '
#              'Preferred Securities',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'C-N',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'a56556fd-c695-46c4-a27b-f9ddd812dd3d',
#      'marginable': True,
#      'name': 'Medley LLC 7.25% Notes due 2024',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MDLQ',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'aa4c9020-0278-41db-b7a2-74218240e07d',
#      'marginable': True,
#      'name': 'TCF Financial Corporation Depositary Shares representing 5.70% '
#              'Series C Non-Cumulative Preferred Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'TCFCP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '5e63c55d-e2a9-434a-a238-ceb8a489be29',
#      'marginable': True,
#      'name': 'E.I. du Pont de Nemours and Company Preferred Stock $3.50 Series',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CTA-A',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'f668bf83-91e2-4a80-9e8f-854562d0ddeb',
#      'marginable': True,
#      'name': 'Atlas Corp. 8.20% Cumulative Redeemable Perpetual Preferred '
#              'Shares - Series G',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ATCO-G',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '879507b9-0d34-43b5-b3ab-64b7ceefd9bd',
#      'marginable': True,
#      'name': 'CHS Inc Preferred Class B Series 2 Reset Rate',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CHSCN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'd4759304-72c8-4994-aabc-0d41ab642708',
#      'marginable': True,
#      'name': 'Healthcare Trust, Inc. 7.375% Series A Cumulative Redeemable '
#              'Perpetual Preferred Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HTIA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '2f3f7a31-985a-45e2-8cb8-4e884f4d6cee',
#      'marginable': True,
#      'name': 'SAFE BULKERS, INC. 8.00%  SER C',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SB-C',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'c9cb1a81-c602-4ad5-a6fc-30c9edc8c46b',
#      'marginable': True,
#      'name': 'Spark Energy, Inc. 8.75% Series A Fixed-to-Floating Rate '
#              'Cumulative Redeemable Perpetual Preferred Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SPKEP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '691a2066-420d-42cb-b22f-b131a7c84395',
#      'marginable': True,
#      'name': 'CHS Inc. Class B Cumulative Redeemable Preferred Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CHSCO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'd74c16fc-ffd6-48da-8334-34490478b70b',
#      'marginable': True,
#      'name': 'Texas Pacific Land Trust',
#      'shortable': True,
#      'status': 'active',
# ...
#      'status': 'active',
#      'symbol': 'MSI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '267f9ea7-eb9a-41cd-946f-5fab57943f0a',
#      'marginable': True,
#      'name': 'ANTHEM, INC.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ANTM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '528e9c38-0e8c-4219-996e-25116168554e',
#      'marginable': True,
#      'name': 'Invesco Solar ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'TAN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '89dcb77e-ca52-42b9-b3b0-ab26f1adf518',
#      'marginable': True,
#      'name': 'Middlefield Banc Corp. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MBCN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '17d926cc-649f-48db-bf8e-330c00067d95',
#      'marginable': True,
#      'name': 'Consumer Portfolio Services, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CPSS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'e5f67d3c-bcf0-42e3-89bf-1b2bf62afff7',
#      'marginable': True,
#      'name': 'Quaker Chemical Corp.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'KWR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'c452d95b-5086-4170-bca2-a0e2e6930ff9',
#      'marginable': True,
#      'name': 'Mirati Therapeutics, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MRTX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'AMEX',
#      'id': '55b25313-9628-4edf-a0a0-f46d19e03740',
#      'marginable': True,
#      'name': 'Bar Harbor Bankshares',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BHB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '1f42101a-e67c-4930-9673-af331ab04d8f',
#      'marginable': True,
#      'name': 'Mednax, Inc (Holding Company)',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MD',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '1f18da2d-2113-49b5-b925-0ec1bee943e9',
#      'marginable': True,
#      'name': 'BLACKROCK CA MUNICIPAL INC TR',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BFZ',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '19926942-ad2d-4432-b910-8931299871db',
#      'marginable': True,
#      'name': 'Invesco BulletShares 2029 Corporate Bond ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BSCT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'AMEX',
#      'id': '27c41b74-a81a-4ac4-86fe-56707b6fd838',
#      'marginable': True,
#      'name': 'Blonder Tongue Laboratories Inc',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BDR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '4acef416-a38b-42e9-9f35-db5742c6f3f0',
#      'marginable': True,
#      'name': 'Medical Properties Trust, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MPW',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '1847c9c5-902d-4538-85c1-cad7a65015a5',
#      'marginable': True,
#      'name': 'Vident Core US Bond Strategy ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'VBND',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'bdacc443-da4a-4512-b4ef-41ab0fc16f82',
#      'marginable': True,
#      'name': 'Outlook Therapeutics, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'OTLK',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '67ad6696-7cbc-413a-acd0-a2d7df817822',
#      'marginable': True,
#      'name': 'MFS High Yield Municipal Trust',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CMU',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '4e025cc8-c1ae-47fc-ae56-dc64f95ba1fb',
#      'marginable': True,
#      'name': 'MFS Municipal Income Trust Shares of Beneficial Interest',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MFM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '35e2d930-207b-44b4-a82e-f024ff12d699',
#      'marginable': True,
#      'name': 'AB Svensk Ekportkredit (Swedish Export Credit Corporation Linked '
#              'to the MLCX Grains Index - Total Re',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'GRU',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '98506868-2d75-4df5-bbc6-5b81c5f8db77',
#      'marginable': True,
#      'name': 'SkyWest, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SKYW',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '85b5d982-da5f-40db-a62c-1826013060b9',
#      'marginable': True,
#      'name': 'Schnitzer Steel Industries, Inc. Class A Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SCHN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '16d20cfc-bc1c-44ee-876e-a6b29dca0e59',
#      'marginable': True,
#      'name': 'ePlus inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'PLUS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': 'd4747b7f-11ef-4349-af4a-1d8e6ad73cf4',
#      'marginable': True,
#      'name': 'iShares S&P  GSCI Commodity-Indexed Trust',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'GSG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': 'a64147a0-dc8e-4bb6-956e-97bde37eca70',
#      'marginable': True,
#      'name': 'Fidelity Targeted Emerging Markets Factor ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'FDEM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'e9dc4275-c166-4ca3-9247-915dbb86fae4',
#      'marginable': True,
#      'name': 'Akcea Therapeutics, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AKCA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'fc43d32a-2fcc-4b9d-a7bf-cbc5f6612d15',
#      'marginable': True,
#      'name': 'GRUPO AVAL ACCIONES Y VALORES S.A.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AVAL',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '77316119-87a4-4e05-9c46-a80b6197fa38',
#      'marginable': True,
#      'name': 'FlexShares Trust FlexShares Credit-Scored US Corporate Bond Index '
#              'Fund',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SKOR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'e38ac953-b460-43ec-80f6-4bb8e3d1f9b1',
#      'marginable': True,
#      'name': 'Nuveen Virginia Quality Municipal Income Fund',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NPV',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '788095f1-2504-4bd3-b502-90bd2f4dece6',
#      'marginable': True,
#      'name': 'Orrstown Financial Services Inc - Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ORRF',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'e72fbd29-be6b-43c2-80c6-b6e80d5b23db',
#      'marginable': True,
#      'name': 'Analog Devices, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ADI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '4cbfe1d7-edee-4f6e-b496-ae0b374f0939',
#      'marginable': True,
#      'name': 'Mohawk Industries, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MHK',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '258b7e12-7f42-4c09-8004-2ba8837f295a',
#      'marginable': True,
#      'name': 'ASA GOLD AND PRECIOUS METALS LIMITED',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ASA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '6cf709f4-6168-422c-8f53-407077194838',
#      'marginable': True,
#      'name': 'ProShares VIX Short-Term Futures ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'VIXY',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'd7a24de1-0d91-4d24-9ad3-aedfc7bf92dc',
#      'marginable': True,
#      'name': 'Xtrackers Russell 1000 Comprehensive Factor ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'DEUS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'e49c3678-30c5-496d-9e57-da080d5b4237',
#      'marginable': True,
#      'name': 'First Trust/Aberdeen Emerging Opportunity Fund',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'FEO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '1cce2bf1-1607-4d2f-af9f-54f0d59524f8',
#      'marginable': True,
#      'name': 'BioCardia, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BCDA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '58beef20-84ee-4ee7-89f2-2c79b6d0c8d7',
#      'marginable': True,
#      'name': 'Suburban Propane Partners L P',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SPH',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '8ef3700c-6883-4987-b0a2-e55e58df386e',
#      'marginable': True,
#      'name': 'UBS AG Exchange Traded Access Securities (E-TRACS)Linked to the '
#              'Wells Fargo Business Development Com',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BDCS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '415bf2a1-61bc-4705-b622-4ab72591b637',
#      'marginable': True,
#      'name': 'TuanChe Limited American Depositary Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'TC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '91a16ebb-93ff-42fc-bd85-574365fe5024',
#      'marginable': True,
#      'name': 'PROTO LABS, INC.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'PRLB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'ea50d3c3-52ce-4fa7-a9ef-ade61941675e',
#      'marginable': True,
#      'name': 'Brainstorm Cell Therapeutics Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BCLI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '0f15a015-738d-4e4d-b890-cf9ff81b470b',
#      'marginable': True,
#      'name': 'Strategic Education, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'STRA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'ce10c6e4-fdae-45ec-8d43-d08b331f68c5',
#      'marginable': True,
#      'name': 'Phibro Animal Health Corporation Class A Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'PAHC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '94feb9d0-bacc-4b3a-9fa7-d372b473c10f',
#      'marginable': True,
#      'name': 'Toronto Dominion Bank',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'TD',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '81b1047d-8c84-44f9-9ee6-59b080a7c8b4',
#      'marginable': True,
#      'name': 'Urban One, Inc. Class D Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'UONEK',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'b599b102-254e-4a5c-838d-8cf26857e562',
#      'marginable': True,
#      'name': 'Tapestry, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'TPR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '420c3bd9-4086-45f1-a95f-978717c57971',
#      'marginable': True,
#      'name': 'SPI Energy Co., Ltd. Ordinary Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SPI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '81e7231c-45c0-423d-935f-de0176a00be3',
#      'marginable': True,
#      'name': 'Atomera Incorporated Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ATOM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'c4e600f3-6406-4325-bc7c-a2e2eba32963',
#      'marginable': True,
#      'name': '2U, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'TWOU',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'db4c8f34-b59c-4c26-a143-5e607afd4a1f',
#      'marginable': True,
#      'name': '1-800-FLOWERS.COM, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'FLWS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'b0d55ff7-f6ab-418a-b0a8-c0a0652f9902',
#      'marginable': True,
#      'name': 'Legg Mason ETF Investment Trust Legg Mason Global Infrastructure '
#              'ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'INFR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': '5ec0d229-c4ea-4ffe-8540-d6abf127b94d',
#      'marginable': True,
#      'name': 'Alpha Architect International Quantitative Momentum ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IMOM',
#      'tradable': True}),
#  ...]

# %%
# Create a new empty DataFrame

# Display the first 10 asset tickers
# Out:
#   symbol
# 0   NUGT
# 1   CNCR
# 2   CODX
# 3   TDOC
# 4   ONEM
# 5   CRAI
# 6   SPWH
# 7   SDPI
# 8   KREF
# 9   NFBK

# %% [markdown]
# ### Get 1 Year's Worth of Data via API Call and Read in as DataFrame

# %%
# Set the ticker


# Set timeframe to '1D'


# Set start and end datetimes of 1 year, between now and 365 days ago.


# Get 1 year's worth of historical data for AAPL
# Out:
#                              AAPL
#                              open     high      low   close    volume
# 2019-11-04 00:00:00-05:00  257.33  257.845  255.380  257.48  23618001
# 2019-11-05 00:00:00-05:00  257.05  258.190  256.320  257.15  17738372
# 2019-11-06 00:00:00-05:00  256.84  257.490  255.365  257.24  15328064
# 2019-11-07 00:00:00-05:00  258.74  260.350  258.110  259.50  22267200
# 2019-11-08 00:00:00-05:00  258.69  260.440  256.850  260.14  15896858

# %% [markdown]
# ### Drop Extraneous Columns

# %%
# Drop Outer Table Level


# Use the drop function to drop extra columns


# Since this is daily data, we can keep only the date (remove the time) component of the data
# Out:
#              close
# 2019-11-04  257.48
# 2019-11-05  257.15
# 2019-11-06  257.24
# 2019-11-07  259.50
# 2019-11-08  260.14

# %% [markdown]
# ### Calculate Daily Returns

# %%
# Use the `pct_change` function to calculate daily returns of AAPL
# Out:
#                close
# 2019-11-04       NaN
# 2019-11-05 -0.001282
# 2019-11-06  0.000350
# 2019-11-07  0.008786
# 2019-11-08  0.002466

# %% [markdown]
# ### Calculate Value of Average Daily Returns

# %%
# Use the `mean` function to calculate the mean of daily returns for AAPL
# Out:
# 0.00017627329176443535

# %% [markdown]
# ### Calculate Value of Standard Deviation of Daily Returns

# %%
# Use the `std` function to calculate the standard deviation of daily returns for AAPL
# Out:
# 0.0338537158765597

# %% [markdown]
# ### Run the Monte Carlo Simulation and Save Results to DataFrame

# %%
# Set number of simulations, trading days, and get last closing price of AAPL from DataFrame


# Initialize empty DataFrame to hold simulated prices for each simulation


# Run the simulation of projecting stock prices for the next trading year, `1000` times


    # Initialize the simulated prices list with the last closing price of AAPL
    
    
    # Simulate the returns for 252 days
    
        # Calculate the simulated price using the last price within the list
      
        # Append the simulated price to the list
        
    
    # Append a simulated prices of each simulation to DataFrame
    

# Print head of DataFrame
# Out:
#    Simulation 1  Simulation 2  Simulation 3  Simulation 4  Simulation 5  \
# 0    247.620000    247.620000    247.620000    247.620000    247.620000
# 1    251.140395    226.578392    238.701769    245.452366    240.466316
# 2    251.020227    228.821290    240.040134    211.763055    243.887612
# 3    249.871533    227.528379    236.257381    214.454368    255.670150
# 4    239.373763    230.001041    236.542415    210.139146    243.446014
#
#    Simulation 6  Simulation 7  Simulation 8  Simulation 9  Simulation 10  ...  \
# 0    247.620000    247.620000    247.620000    247.620000     247.620000  ...
# 1    260.905798    236.653090    246.879579    246.639541     246.214237  ...
# 2    266.543666    243.601366    251.720419    239.748982     249.874300  ...
# 3    253.963951    251.808745    233.723237    231.496334     254.089855  ...
# 4    251.036113    245.155494    243.244514    230.077560     255.417750  ...
#
#    Simulation 991  Simulation 992  Simulation 993  Simulation 994  \
# 0      247.620000      247.620000      247.620000      247.620000
# 1      268.292844      252.990073      258.220309      255.560027
# 2      250.102655      247.108093      251.158419      255.117538
# 3      239.110974      256.279379      267.973287      248.853895
# 4      242.784583      250.433756      277.042076      231.108153
#
#    Simulation 995  Simulation 996  Simulation 997  Simulation 998  \
# 0      247.620000      247.620000      247.620000      247.620000
# 1      248.141880      240.224532      240.301947      257.016841
# 2      250.752595      236.137818      236.277724      239.771826
# 3      264.902247      234.533212      241.355266      245.284077
# 4      258.338287      233.932523      249.864863      242.619205
#
#    Simulation 999  Simulation 1000
# 0      247.620000       247.620000
# 1      253.379147       250.176900
# 2      240.791059       245.964540
# 3      249.340962       242.938863
# 4      251.347876       243.544932
#
# [5 rows x 1000 columns]

# %% [markdown]
# ### Plot the Multiple Simulations of Stock Price Trajectory for AAPL over the Next Year (252 Trading Days)

# %%
# Use the `plot` function to plot the trajectory of AAPL stock based on a 252 trading day simulation

# %%
# Select the last row for project stock prices (prices of each simulation on the 252nd trading day)
# Out:
# Simulation 1    141.597107
# Simulation 2    119.048346
# Simulation 3    163.982639
# Simulation 4    148.526665
# Simulation 5    182.645925
# Name: 252, dtype: float64

# %% [markdown]
# ### Plot the Frequency Distribution of Simulated Ending Prices on 252nd Trading Day

# %%
# Use the `plot` function to plot a frequency distribution of simulated ending prices

# %% [markdown]
# ### Calculate Lower and Upper Bounds of 95% Confidence Interval for Simulated Ending Stock Prices of AAPL

# %%
# Use the `quantile` function to calculate the 95% confidence interval for simulated ending prices
# Out:
# 0.025     78.722927
# 0.975    624.395299
# Name: 252, dtype: float64

# %% [markdown]
# ### Plot the Probability Distribution and 95% Confidence Interval of Simulated Ending Prices

# %%
# Use the `plot` function to create a probability distribution histogram of simulated ending prices
# with markings for a 95% confidence interval

# %% [markdown]
# ### Calculate 95% Confidence Interval of An Initial Investment of 10,000 in AAPL over the Next 252 Trading Days

# %%
# Set initial investment


# Calculate cumulative profit/loss of lower and upper bound


# Add the initial investment to the cumulative profit/loss of lower and upper bound


# Print the results
# Out:
# There is a 95% chance that an initial investment of $10,000 in AAPL over the next 252 trading days will end within in the range of $3179.182894759595 and $25215.867001203784
