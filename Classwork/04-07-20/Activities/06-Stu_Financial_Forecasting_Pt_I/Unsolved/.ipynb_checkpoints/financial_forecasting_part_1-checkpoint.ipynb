# %% [markdown]
# ### Student Activity: Financial Forecasting Part I
#
# This program executes a single simulation of stock price trajectory over the next `252 * 3` trading days (or 3 years of trading) for `TSLA` stock, based on a normal probability distribution of historical daily returns derived from the sample mean and standard deviation.

# %%
# Import libraries and dependencies
import pandas as pd
import numpy as np
import os
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import alpaca_trade_api as tradeapi
# %matplotlib inline

# %%
# Load .env enviroment variables

# Set Alpaca API key and secret
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")

api = tradeapi.REST(alpaca_api_key, alpaca_secret_key, api_version='v2')

# %% [markdown]
# ### Check Available Tickers from Alpaca Markets API

# %%
# Get all Asstes
assets = api.list_assets()

# Keep only tradeable assets
tradeable = [asset for asset in assets if asset.tradable]
tradeable
# Out:
# [Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '9a6b3b30-c141-40f3-8a95-6e9a58a92f55',
#      'marginable': True,
#      'name': 'Medley Capital Corporation 6.50% Notes due 2021',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MCX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'bfd95f49-1392-4002-990c-8fcb1d374f61',
#      'marginable': True,
#      'name': 'Crawford & Company Class B',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CRD.B',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '2ac633b5-b3a7-4ba6-975d-f0f1e12dd1e4',
#      'marginable': True,
#      'name': 'Adobe Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ADBE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '6185a9bc-7fab-4ecb-806f-7f88e5b41e43',
#      'marginable': True,
#      'name': 'Global Beta Smart Income ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'GBDV',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '5bbfee1d-896f-4eec-8484-a4e75f63a8ba',
#      'marginable': True,
#      'name': 'Invesco Dynamic Oil & Gas Services ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'PXJ',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'AMEX',
#      'id': '174cd5bc-f275-4688-86c8-5873f719e7bc',
#      'marginable': True,
#      'name': 'Sachem Capital Corp. Common Shares',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SACH',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '69c0440e-4fe2-4569-8953-33f6268f6990',
#      'marginable': True,
#      'name': 'iShares iBonds Mar 2023 Term Corporate ex-Financials ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IBCE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '9b048da3-d581-4f74-8edf-6921a070ff8d',
#      'marginable': True,
#      'name': 'First US Bancshares, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'FUSB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '9a14561f-ba1b-418d-ad1c-3ef8c8f2f5f6',
#      'marginable': True,
#      'name': 'Momo Inc. American Depositary Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MOMO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '3a64306e-4a77-4a06-8458-15a8bfd31f55',
#      'marginable': True,
#      'name': 'Vanguard Total Stock Market ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'VTI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '9362e926-aafa-47bb-a7e1-b96f1a491b90',
#      'marginable': True,
#      'name': 'Sonnet BioTherapeutics Holdings, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SONN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'ab538748-a391-4503-a30c-6f4f7ef7cfef',
#      'marginable': True,
#      'name': 'Gevo, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'GEVO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '44ddf865-1d4c-443a-b0a4-d8304a703836',
#      'marginable': True,
#      'name': 'Garmin Ltd. Common Stock (Switzerland)',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'GRMN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '4d8f7f83-d998-4839-9134-38473cd13123',
#      'marginable': True,
#      'name': 'Raytheon Technologies Corporation',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'RTX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '762eca63-f335-4d9c-bfc5-83607ad4d8e9',
#      'marginable': True,
#      'name': 'Wynn Resorts, Limited Common stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'WYNN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'e81bb283-b619-4b5d-a356-8af11710d16d',
#      'marginable': True,
#      'name': 'Luther Burbank Corporation Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'LBC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'eeb616dd-e148-4309-826e-6040d6212d13',
#      'marginable': True,
#      'name': 'CSI Compressco LP Common Units',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CCLP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '9764bf4b-b182-4c77-9210-3ea73eb4709c',
#      'marginable': True,
#      'name': 'ClearBridge MLP and Midstream Total Return Fund Inc.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CTR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'a2bbc790-eeeb-442d-a3f2-3b1e2a92be1b',
#      'marginable': True,
#      'name': 'Zentalis Pharmaceuticals, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ZNTL',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '1832937f-f06b-4009-bd7d-0c80369cebfb',
#      'marginable': True,
#      'name': 'Teligent, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'TLGT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'c1decd0c-a5ab-48c8-8d81-b70ffe14cae7',
#      'marginable': True,
#      'name': 'Northwest Natural Holding Company',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'NWN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'a932246c-a62f-46ef-a8a5-2271fa5628be',
#      'marginable': True,
#      'name': 'Vanguard Long-Term Treasury ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'VGLT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '0af9c045-b1d4-4f26-9847-cf5c6f5984af',
#      'marginable': True,
#      'name': 'Otis Worldwide Corporation',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'OTIS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'bc24668d-18b0-41b1-828c-3b57604b1ab2',
#      'marginable': True,
#      'name': 'White Mountains Insurance Group Ltd.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'WTM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '7939b885-c61b-4f74-8c92-ed2734c4293a',
#      'marginable': True,
#      'name': 'T2 Biosystems, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'TTOO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'd174dc71-0a75-47a7-a43c-5cf9360111bf',
#      'marginable': True,
#      'name': 'ETF Series Solutions Trust Loncar Cancer Immunotherapy ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CNCR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'bf458680-b82a-4a80-8ba3-b3fe4e2d3a54',
#      'marginable': True,
#      'name': 'Yunhong International Right',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ZGYHR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'ca43f7b9-bc0c-4cd5-a930-a4c823be5bb7',
#      'marginable': True,
#      'name': 'Carrier Global Corporation',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CARR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '07844fc5-d49c-41dd-a543-dccaf6aec65c',
#      'marginable': True,
#      'name': 'Co-Diagnostics, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CODX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'f9174608-b6bc-4d46-bfc7-4bb761883964',
#      'marginable': True,
#      'name': 'Callon Petroleum Company',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CPE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'd2eb2ae7-fb5e-47d8-a0bf-ff77f0f47f94',
#      'marginable': True,
#      'name': 'Teladoc Health, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'TDOC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'AMEX',
#      'id': '48385aab-a2fe-4ea8-8936-20cbfe4f3dbd',
#      'marginable': True,
#      'name': 'NovaBay Pharmaceuticals, Inc.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NBY',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'af703b23-48ff-407a-aab4-d740200b45fe',
#      'marginable': True,
#      'name': '1Life Healthcare, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ONEM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'e5911d95-c686-4ad9-b9fc-a22da3495566',
#      'marginable': True,
#      'name': 'Garrison Capital Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'GARS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '75b5b1a6-7b48-434c-a2bb-28355a483760',
#      'marginable': True,
#      'name': 'Qraft AI-Enhanced US Large Cap Momentum ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AMOM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '500f4a73-50aa-4ab5-8be0-f1344d6f7181',
#      'marginable': True,
#      'name': 'The Chemours Company',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'ae05bc11-5f0a-4285-98dc-2ceaea44a4c1',
#      'marginable': True,
#      'name': 'Ultralife Corporation Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ULBI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'e90afda6-a12f-4d40-924a-2a373f018d1f',
#      'marginable': True,
#      'name': 'Vanguard S&P 500 Value ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'VOOV',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'effb3765-cd8b-4d42-bdad-ff37eec637c8',
#      'marginable': True,
#      'name': 'Retail Value Inc. Common Shares',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'RVI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '3d305736-a5c2-4d6a-8c1c-a5ee3dc7cca5',
#      'marginable': True,
#      'name': 'Carnival Corporation',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CCL',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '09f86a3f-36b7-4f0b-a50e-a66447b0c4fb',
#      'marginable': True,
#      'name': 'Direxion Daily S&P Oil & Gas Exp. & Prod. Bull 2X Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'GUSH',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': '273b92cc-8a5d-459a-81bd-981d8ed5f89a',
#      'marginable': True,
#      'name': 'iPath Series B S&P 500 VIX Short-Term Futures ETN',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'VXX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '8be77cf5-22fa-4ae8-9b9e-dc48d6aa1282',
#      'marginable': True,
#      'name': 'Yunhong International Class A Ordinary Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ZGYH',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '3ec017af-f24f-4460-a224-f14385931a4a',
#      'marginable': True,
#      'name': "Sportsman's Warehouse Holdings, Inc. Common Stock",
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SPWH',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'f4863c01-fc07-46f2-973d-3f512e8e802d',
#      'marginable': True,
#      'name': 'KKR Real Estate Finance Trust Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'KREF',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '9fb8aeae-3c99-49b2-8ba9-cbbfbba188fd',
#      'marginable': True,
#      'name': 'Direxion Daily FTSE  China Bull 3X Shares',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'YINN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '77e403fc-e120-4f0a-930f-ec90eafb42bd',
#      'marginable': True,
#      'name': 'Emerald Holding, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'EEX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'b28f4066-5c6d-479b-a2af-85dc1a8f16fb',
#      'marginable': True,
#      'name': 'SPDR S&P 500 ETF Trust',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SPY',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': '74852ce1-d5dc-42b7-8f4f-c555d14e79cd',
#      'marginable': True,
#      'name': 'American Century Investments',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'FLV',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '95e2303a-e8c8-4b7e-acc4-6372bf2c9ffa',
#      'marginable': True,
#      'name': 'SPDR S&P Oil & Gas  Equipment & Services ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'XES',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '9cdb7bb7-0a46-4b45-82d7-776c34118502',
#      'marginable': True,
#      'name': 'Bridgford Foods Corporation Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BRID',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '83cb5eb3-5d70-4288-af2f-bf7b92b6ef27',
#      'marginable': True,
#      'name': 'Sprott Physical Gold Trust',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'PHYS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '53adc2e4-2912-43be-b193-8f053c15d219',
#      'marginable': True,
#      'name': 'Endeavour Silver Corp.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'EXK',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'a6c71791-d4a7-4b9f-bfa8-1a09447636cb',
#      'marginable': True,
#      'name': 'MorphoSys AG American Depositary Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MOR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'BATS',
#      'id': 'f0c2c1a9-df3c-4d3d-88a1-da594ef53ff9',
#      'marginable': True,
#      'name': 'VanEck Vectors CEF Municipal Income ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'XMPT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '28d064f9-1f9c-4aec-bd47-0b7f3dd08d98',
#      'marginable': True,
#      'name': 'iShares Morningstar Large-Cap ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'JKD',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'cdc0c039-07a4-4749-8b01-c3589c8eff8b',
#      'marginable': True,
#      'name': 'Eaton Vance Senior Income Trust',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'EVF',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'acbd461e-ba1d-470a-877c-526f44a4d91f',
#      'marginable': True,
#      'name': 'Tortoise Acquisition Corp. Class A Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SHLL',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '0af66fd5-01dd-45dc-8bc8-0d9b0515f5c5',
#      'marginable': True,
#      'name': 'Schwab Emerging Markets Equity ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SCHE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'de80af50-a26c-4a70-b1cb-3b4784d7cdde',
#      'marginable': True,
#      'name': 'Stanley Black & Decker, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SWK',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'd3e476f4-9cda-414d-a333-6da283845ea5',
#      'marginable': True,
#      'name': 'Taronis Technologies, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'TRNX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '5073fed7-529f-412b-826f-36b93e40ed4c',
#      'marginable': True,
#      'name': 'Graphic Packaging Holding Company',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'GPK',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'ac0a5ab3-c262-428e-84b8-eb8af07274bf',
#      'marginable': True,
#      'name': 'PBF LOGISTICS LP',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'PBFX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'b4219334-aa87-4166-82cc-4f262a0ca36a',
#      'marginable': True,
#      'name': 'Churchill Capital Corp III Class A Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CCXX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'd414546c-2622-4d1a-bf12-2a68636f5a87',
#      'marginable': True,
#      'name': 'CRA International, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CRAI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '256e3ebe-e1a9-4846-a841-d0b40e2d9753',
#      'marginable': True,
#      'name': 'CITIC Capital Acquisition Corp. Class A Ordinary Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CCAC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': 'd5daeb9d-d475-45f9-9e62-da2b3ccb42c0',
#      'marginable': True,
#      'name': 'American Century Investments',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'FDG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'AMEX',
#      'id': '81d4c0f0-a661-4da4-b379-3de39327e4e5',
#      'marginable': True,
#      'name': 'Superior Drilling Products Inc.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SDPI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '18d9d76d-f4dd-4d97-9209-c58826d43f7d',
#      'marginable': True,
#      'name': 'Northfield Bancorp, Inc. Common Stock (Delaware)',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'NFBK',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '66c2dc19-a4a9-460d-9a4f-f9ba05873ca0',
#      'marginable': True,
#      'name': 'Aptiv PLC',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'APTV',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '719ab4de-ac40-4103-8766-2602fa7f82ad',
#      'marginable': True,
#      'name': 'Genocea Biosciences, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'GNCA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '02b6820c-e5d5-462f-b3d0-d600919dffd7',
#      'marginable': True,
#      'name': 'Direxion Daily Gold Miners Index Bull 2X Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NUGT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'd2bee994-8a9c-4097-9d48-9d568f6c8764',
#      'marginable': True,
#      'name': 'Aptevo Therapeutics Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'APVO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '5ec683da-c77e-4a12-9a4c-db932340d47c',
#      'marginable': True,
#      'name': 'Direxion Daily Latin America Bull 3X Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'LBJ',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '9b5d6522-a345-467b-bf03-013a10c354d4',
#      'marginable': True,
#      'name': 'SPDR Bloomberg Barclays High Yield Bond ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'JNK',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '290d671d-6c20-44e8-b35b-84c4068954ac',
#      'marginable': True,
#      'name': 'RiverNorth Flexible Municipal Income Fund, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'RFM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '7595a8d2-68a6-46d7-910c-6b1958491f5c',
#      'marginable': True,
#      'name': 'Agilent Technologies Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'A',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'ad22d1ca-8bfc-45cc-ae7f-5f091bbc8c7c',
#      'marginable': True,
#      'name': 'Bristol-Myers Squibb Co.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BMY',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '91b18f9e-580f-4b08-b7a1-dd5fa4542485',
#      'marginable': True,
#      'name': 'Verrica Pharmaceuticals Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'VRCA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '6c7a2f3c-c601-483a-bf33-c52dc99e0505',
#      'marginable': True,
#      'name': 'Fidelity Small-Mid Factor ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'FSMD',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': '0d82e509-9040-4a32-9190-43b53b8f0c39',
#      'marginable': True,
#      'name': 'Innovator Nasdaq-100 Power Buffer ETF - April',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NAPR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '4727bfe5-6f9d-4a88-84bb-4af1cbeebc12',
#      'marginable': True,
#      'name': 'JPMorgan Chase & Co. Depositary Shares, each representing a '
#              '1/400th interest in a share of JPMorgan',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'JPM-J',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'cb509111-b8f2-453d-a060-46f054d7ad7d',
#      'marginable': True,
#      'name': 'Wells Fargo & Company Depositary Shares, each representing a '
#              '1/1,000th interest in a share of Non-Cu',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'WFC-W',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '034e2e67-e61e-480b-a7f6-82a7b9ac6363',
#      'marginable': True,
#      'name': 'Independent Bank Corp. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'INDB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '9b37dd2d-960c-46b7-a914-eba6b21e0b99',
#      'marginable': True,
#      'name': 'Merrimack Pharmaceuticals, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MACK',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '1d4057ea-2549-477b-89b9-a524437ec1ee',
#      'marginable': True,
#      'name': 'Galera Therapeutics, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'GRTX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'AMEX',
#      'id': '4a63bc78-fa4c-494a-836c-467cccb1d17a',
#      'marginable': True,
#      'name': 'Aberdeen Emerging Markets Equity Income Fund, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AEF',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '69d0bd9e-1a66-4c39-a200-c0ef67ac4d69',
#      'marginable': True,
#      'name': 'Brookfield Renewable Partners L.P. 5.25% Class A Preferred '
#              'Limited Partnership Units, Series 17',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BEP-A',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '55f1d3fb-6a2b-4e1e-b852-7464dbc91dcd',
#      'marginable': True,
#      'name': 'iShares S&P Mid-Cap 400 Growth ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IJK',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'f3668eac-5d4c-48a9-b83e-78ad34237e70',
#      'marginable': True,
#      'name': 'FVCBankcorp, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'FVCB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'b4dfeef6-1873-4fb5-b2b7-086e85c45ac4',
#      'marginable': True,
#      'name': 'Aptose Biosciences, Inc. Common Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'APTO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'e9acabb4-a4c2-45e7-bc57-58968954c906',
#      'marginable': True,
#      'name': 'iShares Trust iShares iBonds Dec 2024 Term Treasury ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IBTE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'e930cf4f-6b04-4a7e-85e6-ad1b01cd3c17',
#      'marginable': True,
#      'name': 'Southwest Airlines Co.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'LUV',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '69449ae5-8790-4ed5-94a8-b54c4e98f9c7',
#      'marginable': True,
#      'name': 'SPDR S&P Oil & Gas Exploration & Production ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'XOP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '98f3edde-a927-4703-a66e-5cfb1626c51b',
#      'marginable': True,
#      'name': 'Direxion Daily MSCI Mexico Bull 3X Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MEXX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '7f9df478-237c-45c8-bc80-c97a53478c37',
#      'marginable': True,
#      'name': 'T-Mobile US, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'TMUS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '2d9e926c-e17c-47c3-ad8c-26c7a594e48f',
#      'marginable': True,
#      'name': 'Invesco QQQ Trust, Series 1',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'QQQ',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'd59870fe-9add-43f2-960c-b2ec4f29d8d3',
#      'marginable': True,
#      'name': 'Dow Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'DOW',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '5344140c-ca01-4435-8a4a-217d4496bd35',
#      'marginable': True,
#      'name': 'ZOETIS INC.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ZTS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '3e935d55-1356-4a24-91c3-f4e72f67c333',
#      'marginable': True,
#      'name': 'Xtrackers Low Beta High Yield Bond ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HYDW',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'dc7a80eb-5e2b-44ac-8969-416bd4d8e835',
#      'marginable': True,
#      'name': 'ProShares Trust ProShares UltraShort Nasdaq Biotechnology',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BIS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'AMEX',
#      'id': 'db6e0b9b-d6e4-4622-9708-708eb9115a14',
#      'marginable': True,
#      'name': 'The Gabelli Global Utility & Income Trust Series B Cumulative '
#              'Puttable and Callable Preferred Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'GLU-B',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '0a8048c4-2f82-450f-8a33-ebac07282c46',
#      'marginable': True,
#      'name': 'Epsilon Energy Ltd. Common Share',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'EPSN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'bcd778fc-d401-4912-879d-770f8fdf1588',
#      'marginable': True,
#      'name': 'WELLS FARGO & COMPANY Depositary Shares, each representing a '
#              '1/1,000th interest in a share of Non-Cu',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'WFC-O',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'f5915306-c109-4982-a0d9-1ea2eb60a6a1',
#      'marginable': True,
#      'name': 'iShares MSCI Indonesia ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'EIDO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'd05c4704-71e6-4c6b-932b-b3e7614f2b7e',
#      'marginable': True,
#      'name': 'AEGON N.V.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AEG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'AMEX',
#      'id': 'd94309d6-302a-4bd8-9380-de81d12d92bd',
#      'marginable': True,
#      'name': 'Clough Global Opportunities Fund',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'GLO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '252e9b06-9d31-495b-a95c-ef0a61ebb65b',
#      'marginable': True,
#      'name': 'BioDelivery Sciences International, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BDSI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '2ebca25c-c3c3-47fd-b703-8b197574c929',
#      'marginable': True,
#      'name': 'Five Prime Therapeutics, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'FPRX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'a3dc580e-26d3-4521-bcc6-7ab64b55ad0e',
#      'marginable': True,
#      'name': 'Insight Select Income Fund',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'INSI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '84299156-28e6-4746-a1c8-e91bf21cf128',
#      'marginable': True,
#      'name': 'Ashland Global Holdings Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ASH',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'a4447cf9-9adb-48f2-b71d-68508c3bd7bf',
#      'marginable': True,
#      'name': 'Qudian Inc. American Depositary Shares, each representing one '
#              'Class A Ordinary Share',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'QD',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '1b10616e-7e2b-42e8-9141-350e97fb5615',
#      'marginable': True,
#      'name': 'ProShares Ulta SmallCap600',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SAA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'ddac09a2-793e-416a-b96b-a44c5f21ef65',
#      'marginable': True,
#      'name': 'Amneal Pharmaceuticals, Inc. Class A Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'AMRX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'e0060798-2d3d-4c43-857e-f10508d0be87',
#      'marginable': True,
#      'name': 'Churchill Downs, Incorporated Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CHDN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'bbbd5619-3cbc-4498-938e-41532420f1cc',
#      'marginable': True,
#      'name': 'B. Riley Financial, Inc. 6.50% Senior Notes Due 2026',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'RILYN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '97d48d26-0ced-46d2-b1d2-818b682c9c15',
#      'marginable': True,
#      'name': 'First Trust Exchange-Traded Fund VI First Trust Nasdaq Retail ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'FTXD',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '08bb405e-5d77-4998-b998-6690668cc86a',
#      'marginable': True,
#      'name': 'AdvisorShares Trust AdvisorShares Dorsey Wright FSM All Cap World '
#              'ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'DWAW',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'fba32604-7996-454c-9678-67400ba7cdfb',
#      'marginable': True,
#      'name': 'Global X MSCI China Information Technology ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CHIK',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '57d020fb-b12e-4b9b-bc94-b22f1146cc05',
#      'marginable': True,
#      'name': 'Entravision Communication',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'EVC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'd85ddcb9-82b2-44cc-b859-b39669036aee',
#      'marginable': True,
#      'name': 'Valley National Bancorp Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'VLY',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '914726ec-6719-4bd1-b883-504617a3d520',
#      'marginable': True,
#      'name': 'Invesco S&P 500 Top 50 ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'XLG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '6ca352cd-6b3e-4267-b5a4-ca1498117b57',
#      'marginable': True,
#      'name': 'MEXICO FUND',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MXF',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '3d21888c-64aa-4b72-b07e-29d1c3694bef',
#      'marginable': True,
#      'name': 'EVO Payments, Inc. Class A Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'EVOP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'c212e219-b17d-4ff1-99dd-30e3896122a3',
#      'marginable': True,
#      'name': 'Pentair plc',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'PNR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '27510e06-9235-4a34-ae47-05005c0e55ce',
#      'marginable': True,
#      'name': 'Guangshen Railway Co. Ltd',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'GSH',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '4b1a698e-e254-463d-8a87-9eeae1e04905',
#      'marginable': True,
#      'name': 'InVivo Therapeutics Holdings Corp Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'NVIV',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'AMEX',
#      'id': '7c4d7611-6242-4f35-8082-c038e375d8a9',
#      'marginable': True,
#      'name': 'Gran Tierra Energy Inc.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'GTE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '23b2320f-55ee-4ee1-ae5e-99552d5b7247',
#      'marginable': True,
#      'name': 'Capital One Financial Corporation',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'COF-F',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '9d0641f7-458f-408e-978d-75606692a0cd',
#      'marginable': True,
#      'name': 'F.N.B. CORPORATION Representing a 1/40th Interest in a Share of '
#              'Fixed-to-Floating Rate Non-Cumulativ',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'FNB-E',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '54345b1a-c677-4237-9861-ea8fe24c8144',
#      'marginable': True,
#      'name': 'Support.com, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SPRT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '406e1717-5f0f-4e8e-b990-719c6ba62d25',
#      'marginable': True,
#      'name': 'National Grid PLC',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'NGG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '282183d3-d2f1-4ecc-9ec8-db9648ff0035',
#      'marginable': True,
#      'name': 'Cambium Networks Corporation Ordinary Shares',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CMBM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '88c21448-369e-4c4c-88db-8e120159fcc5',
#      'marginable': True,
#      'name': 'Vonage Holdings Corp. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'VG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'AMEX',
#      'id': '07225093-1a4e-4977-8de3-8484064cb807',
#      'marginable': True,
#      'name': 'Howmet Aerospace Inc. $3.75 Cumulative Preferred Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HWM-',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'b249700b-760b-466b-a2be-753ae6acd603',
#      'marginable': True,
#      'name': 'Meten EdtechX Education Group Ltd. Ordinary Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'METX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': 'e1606c98-c236-4cc6-9dd0-206bdb132010',
#      'marginable': True,
#      'name': 'Esoterica NextG Economy ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'WUGI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '05a360ff-d443-48c2-9eee-361f9e663732',
#      'marginable': True,
#      'name': 'Invesco Exchange-Traded Fund Trust Invesco Water Resources ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'PHO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '639d865b-fd4c-49b1-9a67-58421d6a01f4',
#      'marginable': True,
#      'name': 'John Hancock Multifactor Developed International ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'JHMD',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '08fcb75d-c165-4928-977d-3fe3d026f881',
#      'marginable': True,
#      'name': 'Arconic Corporation',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ARNC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '459561d5-3be1-43f0-89d0-44edf751c9b2',
#      'marginable': True,
#      'name': 'WiMi Hologram Cloud Inc. American Depositary Share',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'WIMI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '6f9bf0b0-4114-495f-87e4-720b2db3772a',
#      'marginable': True,
#      'name': 'Howmet Aerospace Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'HWM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '12a016ea-60da-4795-8926-1ed6aa9357aa',
#      'marginable': True,
#      'name': 'Allied Healthcare Products, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AHPI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '5392afba-15e4-41ef-9dc6-698e14099132',
#      'marginable': True,
#      'name': 'Partner Communications Company Ltd. American Depositary Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'PTNR',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'f792de6d-9633-4327-b29e-3ae13bd3ab02',
#      'marginable': True,
#      'name': 'IDEAYA Biosciences, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IDYA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'b42e5b13-8e36-4728-b960-a3cbfd76e906',
#      'marginable': True,
#      'name': 'B. Riley Financial, Inc. 6.375% Senior Notes due 2025',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'RILYM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '51c8b6bc-75be-4536-81e4-64985133f010',
#      'marginable': True,
#      'name': 'Piedmont Office Realty Trust, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'PDM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '892f2850-0d47-4d61-ac9e-fd80f1a8f405',
#      'marginable': True,
#      'name': 'UBS AG FI Enhanced Large Cap Growth ETN',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'FBGX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '56a6b4fd-1f0b-4350-8e29-214e3120a8aa',
#      'marginable': True,
#      'name': 'VictoryShares US 500 Enhanced Volatility Wtd ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CFO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '531b9585-e21c-425d-b69d-c5ed8586ae9c',
#      'marginable': True,
#      'name': 'Ready Capital Corporation 6.50% Senior Notes due 2021',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'RCP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '0d2a52e3-a0ce-4cb0-a0b4-eaf3b8296cb2',
#      'marginable': True,
#      'name': 'Nektar Therapeutics  Common Stock',
#      'shortable': True,
# ...
#      'exchange': 'ARCA',
#      'id': '9d780756-c8d8-48b7-9637-9962aa8d5645',
#      'marginable': True,
#      'name': 'First Trust Horizon Managed Volatility Developed International '
#              'ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'HDMV',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': '558cb378-80f5-41f5-97fa-ed0c4b0ff41e',
#      'marginable': True,
#      'name': 'Anfield Capital Diversified Alternatives ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'DALT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'bd3819a2-2109-4a1a-a6eb-eae95501bc7e',
#      'marginable': True,
#      'name': 'Artesian Resources Corporation Class A Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'ARTNA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': 'e077638f-a5c9-47e4-a7ce-2bfabf5ff698',
#      'marginable': True,
#      'name': "McDonald's Corporation",
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'MCD',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '3866def6-d71b-4c63-8fb9-fc32f7bccfc0',
#      'marginable': True,
#      'name': 'Scorpio Tankers Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'STNG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'ea7afd19-72b9-48cf-9f8b-1d9738870a24',
#      'marginable': True,
#      'name': 'IEC Electronics Corp. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'IEC',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '1fbfe5f5-3bf0-4867-9c9a-200b03fd3635',
#      'marginable': True,
#      'name': 'First Trust Exchange-Traded Fund VI First Trust SMID Cap Rising '
#              'Dividend Achievers ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SDVY',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': 'cb5d3ee4-6313-41ac-9927-fb210baa2f80',
#      'marginable': True,
#      'name': 'United States Natural Gas Fund, LP Unit',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'UNG',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '7218c523-1b5e-4066-8e14-fd3514ca6550',
#      'marginable': True,
#      'name': 'HealthStream, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'HSTM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '34e3f47b-07e6-461f-9af7-3c1a02ea0d5d',
#      'marginable': True,
#      'name': 'COSTAMARE INC. 8.50% Series C Cumulative Redeemable Perpetual '
#              'Preferred Stock, $0.0001 par value',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CMRE-C',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '19308edb-9ab4-4698-9902-31aee1dcca55',
#      'marginable': True,
#      'name': 'ALPS Medical Breakthroughs ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SBIO',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '15b3b092-6017-43ed-b546-69a0d7170b87',
#      'marginable': True,
#      'name': 'KraneShares MSCI Emerging Markets Ex China Index ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'KEMX',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '5ebc08a7-ff4f-4fa9-8406-ddec5caf96f4',
#      'marginable': True,
#      'name': 'IF Bancorp, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IROQ',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '7ae89790-6169-4f6e-b377-8a9bdd395052',
#      'marginable': True,
#      'name': 'Citizens, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CIA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'BATS',
#      'id': 'cf10c9a5-4ac7-435b-87f8-9fa23a233546',
#      'marginable': True,
#      'name': 'iShares Edge MSCI Min Vol USA Small-Cap ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SMMV',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'af148984-c61a-4165-9181-2122e18bb29b',
#      'marginable': True,
#      'name': 'Hartford Multifactor US Equity ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'ROUS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '42605dbb-b379-418f-975d-048bb77be696',
#      'marginable': True,
#      'name': 'Infosys Limited American Depositary Shares',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'INFY',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'df913064-06d2-40c3-99ad-b91d96465c8b',
#      'marginable': True,
#      'name': 'iShares MSCI All Country Asia ex Japan ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AAXJ',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'c74fd973-fead-4d13-b9b9-fad571d49e82',
#      'marginable': True,
#      'name': 'Saratoga Investment Corp. 6.25% Notes due 2025',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SAF',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '43418646-dd32-4887-b5f6-5e3dd7734d41',
#      'marginable': True,
#      'name': 'DeltaShares S&P EM 100 & Managed Risk ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'DMRE',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'e537fc6f-fe8b-4003-927c-872f6749a7ea',
#      'marginable': True,
#      'name': 'Medalist Diversified REIT, Inc. Series A Cumulative Redeemable '
#              'Preferred Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MDRRP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '7a6f2c3e-7b02-483c-8ea5-6f825145075c',
#      'marginable': True,
#      'name': 'CBM Bancorp, Inc. Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CBMB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'AMEX',
#      'id': '97ae307b-9a9e-428f-b9e1-7f8b6e9cf214',
#      'marginable': True,
#      'name': 'Metalla Royalty & Streaming Ltd.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'MTA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '6309e6fb-d02c-4c7d-91dc-a08682892057',
#      'marginable': True,
#      'name': 'UMH Properties, Inc. 6.75% Series C Cumulative Redeemable '
#              'Preferred Stock, Liquidation Preference $2',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'UMH-C',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '8c59278d-8323-49b5-847f-4161159a1cc2',
#      'marginable': True,
#      'name': 'Brookfield Property Partners L.P. 6.50% Class A Cumulative '
#              'Redeemable Perpetual Preferred Units',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'BPYPP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '45075c39-d626-4789-a8b0-03bc9f13fb4a',
#      'marginable': True,
#      'name': 'Janus Henderson Short Duration Income ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'VNLA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'd2c53484-bd7e-4502-9e66-a0829c413b15',
#      'marginable': True,
#      'name': 'First Trust Exchange-Traded Fund III First Trust RiverFront '
#              'Dynamic Emerging Markets ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'RFEM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '4df570de-5f7d-4645-b098-a0148d7ae677',
#      'marginable': True,
#      'name': 'Invesco MSCI Global Timber ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CUT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '89dd47f1-3e5d-4c31-8fbf-62c6f1649a5f',
#      'marginable': True,
#      'name': 'CorEnergy Infrastructure Trust, Inc Depositary Shares '
#              'representing a 1/100th fractional interest of',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'CORR-A',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '97ee2d59-cc21-451b-b65f-014f36bb5a45',
#      'marginable': True,
#      'name': 'iShares Core Moderate Allocation ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AOK',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '50864234-1e14-4d3f-b3f9-8ea53e700800',
#      'marginable': True,
#      'name': 'The Bank of Princeton Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BPRN',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'ARCA',
#      'id': '9f77ed09-d248-47f7-85c2-598b817fff8c',
#      'marginable': True,
#      'name': 'Industrial Select Sector SPDR Fund',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'XLI',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': '5611fcba-af4b-4ab7-9c23-f1683567a933',
#      'marginable': True,
#      'name': 'Equity Commonwealth 6 1/2% Series D Cumulative Convertible '
#              'Preferred Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'EQC-D',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '192840c5-efb8-4f07-a4a3-ab58bc0fb05f',
#      'marginable': True,
#      'name': 'Universal Health Realty Income Trust',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'UHT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '0666dd39-e7df-4e09-90e6-bd1a2b42a3c1',
#      'marginable': True,
#      'name': 'CenterPoint Energy, Inc.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'CNP',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'd340ec75-7bb2-46fa-bee9-42b7e3b4cc11',
#      'marginable': True,
#      'name': 'The Gabelli Equity Trust Inc.',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'GAB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '56125588-caa3-496f-a795-6757ba4e94b3',
#      'marginable': True,
#      'name': 'PEMBINA PIPELINE CORPORATION',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'PBA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '664c71d6-c62a-4618-9831-756a3ef74ae8',
#      'marginable': True,
#      'name': 'Brown-Forman Corporation Class A',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'BF.A',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': '63ab07b9-b1d5-4a3a-95e1-73b60444bcae',
#      'marginable': True,
#      'name': 'Vanguard Scottsdale Funds Vanguard Russell 1000 Value ETF',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'VONV',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': 'b91e1c85-3996-4b85-9e09-09869da2a4de',
#      'marginable': True,
#      'name': 'Franklin LibertyQ Global Dividend ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'FLQD',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '58e6752b-80d8-4ee2-a2e0-1f1327540628',
#      'marginable': True,
#      'name': 'Sinovac Biotech, Ltd. Ordinary Shares',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'SVA',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '2699cd5c-0240-4712-8bee-6e7cf51cfe13',
#      'marginable': True,
#      'name': 'Summit Materials, Inc. Class A Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SUM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NYSE',
#      'id': 'ea5bf24b-14ef-4fe0-9d92-5fe7c1ba2769',
#      'marginable': True,
#      'name': 'Fortive Corporation 5.00% Mandatory Convertible Preferred Stock, '
#              'Series A',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'FTV-A',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'ARCA',
#      'id': '2b339867-cf75-4afa-8a8d-c8e1825cbe4b',
#      'marginable': True,
#      'name': 'John Hancock Multifactor Technology ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'JHMT',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': 'aef76cf6-b8d7-4cff-8ab1-72311d7e2a66',
#      'marginable': True,
#      'name': 'iShares Intermediate-Term Corporate Bond ETF',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'IGIB',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': False,
#      'exchange': 'NASDAQ',
#      'id': '03fb07bb-5db1-4077-8dea-5d711b272625',
#      'marginable': True,
#      'name': 'Advanced Micro Devices, Inc. Common Stock',
#      'shortable': False,
#      'status': 'active',
#      'symbol': 'AMD',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NYSE',
#      'id': '538a8560-35c9-41e1-b4a7-0be36c714101',
#      'marginable': True,
#      'name': 'Federal Signal Corp.',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'FSS',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'b2015fd4-d4d1-4c80-8e20-394862c1b63d',
#      'marginable': True,
#      'name': 'Sanmina Corporation Common Stock',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'SANM',
#      'tradable': True}),
#  Asset({   'class': 'us_equity',
#      'easy_to_borrow': True,
#      'exchange': 'NASDAQ',
#      'id': 'fab07980-45f8-4bcc-852b-90b9b1b5a0b9',
#      'marginable': True,
#      'name': 'StoneCo Ltd. Class A Common Shares',
#      'shortable': True,
#      'status': 'active',
#      'symbol': 'STNE',
#      'tradable': True}),
#  ...]

# %%
# Create a new empty DataFrame
asset_info_df = pd.DataFrame()
asset_info_df['symbol'] = pd.Series([asset.symbol for asset in assets])
# Display the first 10 asset tickers
asset_info_df.head(10)
# Out:
#            symbol
# 0             MCX
# 1           CRD.B
# 2            ADBE
# 3            GBDV
# 4             PXJ
# 5            SACH
# 6  SAMAU_DELISTED
# 7            IBCE
# 8  KYOCY_DELISTED
# 9            FUSB

# %% [markdown]
# ### Get 1 Year's Worth of Data via API Call and Read in as DataFrame

# %%
# Set the ticker
ticker = 'TSLA'

# Set timeframe to '1D'
timeframe = '1D'

# Set start and end datetimes of 1 year, between now and 365 days ago.
end_date = datetime.now()
start_date = end_date + timedelta(-365)


# Get 1 year's worth of historical data for TSLA
df = api.get_barset(
    ticker,
    timeframe,
    limit=None,
    start=start_date,
    end=end_date,
    after=None,
    until=None,
).df

df.head()
# Out:
#                                TSLA
#                                open    high     low   close   volume
# 2019-11-13 00:00:00-05:00  355.0000  356.33  345.18  345.99  8029488
# 2019-11-14 00:00:00-05:00  346.1100  353.84  342.91  349.36  5966623
# 2019-11-15 00:00:00-05:00  350.6400  352.80  348.36  352.24  4591478
# 2019-11-18 00:00:00-05:00  352.9165  353.15  346.10  349.98  4287780
# 2019-11-19 00:00:00-05:00  351.7500  359.99  347.80  359.52  7442184

# %% [markdown]
# ### Drop Extraneous Levels and Columns

# %%
# Drop Outer Table Level
df = df.droplevel(axis=1,level=0)

# Use the drop function to drop extra columns
df.drop(columns=['open', 'high', 'low', 'volume'], inplace=True)

# Since this is daily data, we can keep only the date (remove the time) component of the data
df.index = df.index.date
df.head()
# Out:
#              close
# 2019-11-13  345.99
# 2019-11-14  349.36
# 2019-11-15  352.24
# 2019-11-18  349.98
# 2019-11-19  359.52

# %% [markdown]
# ### Calculate Daily Returns

# %%
# Use the `pct_change` function to calculate daily returns of TSLA
# Out:
#                close
# 2019-11-04       NaN
# 2019-11-05 -0.000835
# 2019-11-06  0.030079
# 2019-11-07  0.026599
# 2019-11-08  0.005158

# %% [markdown]
# ### Calculate Value of Average Daily Returns

# %%
# Use the `mean` function to calculate the mean of daily returns for TSLA
# Out:
# 0.006724657991054274

# %% [markdown]
# ### Calculate Value of Standard Deviation of Daily Returns

# %%
# Use the `std` function to calculate the standard deviation of daily returns for TSLA
# Out:
# 0.06056369619711004

# %% [markdown]
# ### Run the Monte Carlo Simulation and Save Results to DataFrame

# %%
# Set number of trading days and get last closing price of TSLA from DataFrame


# Initialize the simulated prices list with the last closing price of TSLA


# Simulate the returns for 252 * 3 trading days

    # Calculate the simulated price using the last price within the list

    # Append the simulated price to the list

    
# Create a DataFrame of the simulated prices


# Print head of DataFrame
# Out:
#    Simulated TSLA Prices
# 0             514.560000
# 1             562.327640
# 2             528.121625
# 3             563.521309
# 4             612.765868

# %% [markdown]
# ### Plot the Simulated Stock Price Trajectory for TSLA over the Next 3 Years (252 * 3) of Trading Days

# %%
# Use the `plot` function to plot the trajectory of TSLA stock based on a (252 * 3) trading day simulation

# %% [markdown]
# ### Calculate Daily Returns of Simulated Stock Prices for TSLA

# %%
# Use the `pct_change` function to calculate daily returns of simulated stock prices for TSLA
# Out:
#    Simulated TSLA Prices
# 0                    NaN
# 1               0.092832
# 2              -0.060829
# 3               0.067029
# 4               0.087387

# %% [markdown]
# ### Calculate the Cumulative Returns of Simulated Stock Prices for TSLA

# %%
# Use the `cumprod` function to calculate the cumulative returns of simulated stock prices for TSLA
# Out:
#    Simulated TSLA Prices
# 0                    NaN
# 1               1.092832
# 2               1.026356
# 3               1.095152
# 4               1.190854

# %% [markdown]
# ### Calculate the Cumulative Profits/Losses of Simulated Stock Prices for TSLA

# %%
# Multiply an initial investment by the cumulative returns of simulative stock prices to
# return the progression of cumulative returns in terms of money
# Out:
#    Simulated TSLA Prices
# 0                    NaN
# 1           10928.320109
# 2           10263.557705
# 3           10951.517969
# 4           11908.540653

# %% [markdown]
# ### Plot the Cumulative Profits/Losses of `$10,000` in TSLA Over the Next 3 Years (252 * 3) of Trading Days

# %%
# Use the 'plot' function to create a chart of the cumulative profits/losses
